# %% [markdown]
# This script contains some improvement from train.ipynb by default:
# * much few layers, heads, and embedding dimension to reduce the model size
# * dataloader v2 which uses a custom tokenizer (again to reduce model size)
# * no positional embeddings (to reduce model complexity)
# * weight tying (to reduce model size)
#
#
# We implemented a few things here first and not before:
# * validation losses
# * increased the model size to be just below 30M parameters
# * reduced the amount of data trained with to keep the training (wall) time consistent
# * made graph more informative

# %% [markdown]
# This script contains a couple improvements from train2.ipynb:
# * gradient accumulation is enabled
# * the dataloader chunks from the start of an example up to the max_length or the endoftext token

# %% [markdown]
# This contains some changes from train3.ipynb:
# * an accuracy metric has been implemented
# * one cycle learning rate schedule is being used
# * weight tying is disabled

# %% [markdown]
# This contains some improvements from train4.ipynb: just that the attention module used uses pytorchs implementation for sdpa. This also uses a text generation function to display the capabilities of the trained model.

# %%
import socket
socket.gethostname()
# Out:
# 'DESKTOP-ISTII7E'

# %%
GPT_CONFIG_30M = {
    "vocab_size": 30002,
    "context_length": 256,
    "emb_dim": 512,
    "n_heads": 4,
    "n_layers": 4,
    "drop_rate": 0.0,
    "qkv_bias": False,
    "weight_tying": True,
    "no_pos_emb": True
}

# %%
GPT_CONFIG_60M = {
    "vocab_size": 30002,
    "context_length": 512,
    "emb_dim": 512,
    "n_heads": 8,
    "n_layers": 8,
    "drop_rate": 0.0,
    "qkv_bias": False,
    "weight_tying": False,
    "no_pos_emb": True
}

# %%
import socket
hostname = socket.gethostname().lower()
if "laptop" in hostname:
    GPT_CONFIG = GPT_CONFIG_30M
else:
    GPT_CONFIG = GPT_CONFIG_60M

# %%
import torch.nn as nn
import torch

torch.set_float32_matmul_precision('medium')

# %%
trainer_config = {
    "dataset_scale": 3,
    "batch_size": 32 if "laptop" in hostname else 16,
    "epochs": 1,
    "train_file_loc": "../data/TinyStories/TinyStoriesV2-GPT4-train.txt",
    "valid_file_loc": "../data/TinyStories/TinyStoriesV2-GPT4-valid.txt",
    "num_workers": 11 if "laptop" in hostname else 23,
    "max_lr": 1e-3,
    "compile": "laptop" not in hostname
}
trainer_config["grad_batches"] = 256 // trainer_config["batch_size"]

# %%
from components.gptmodel import GPTModel_v2
from torch.optim.lr_scheduler import OneCycleLR
from components.data import create_dataloader_v3
import lightning as L

class LitGPTModel(L.LightningModule):
    def __init__(self, trainer_config, gpt_config):
        super().__init__()
        self.gpt_config = gpt_config
        self.trainer_config = trainer_config

        self.train_accuracy = []
        self.val_accuracy = []
        self.train_losses = []
        self.val_losses = []
        self.val_steps = []
        self.learning_rates = []
        self.batch_step = 0

    def _accuracy(self, output, expected):
        total_matching = (torch.argmax(output, dim=-1) == expected).sum().item()
        total_numel = expected.numel()
        return total_matching / total_numel

    def training_step(self, batch, batch_idx):
        self.batch_step += 1
        x, y = batch
        logits = self.model(x)

        accuracy = self._accuracy(logits, y)
        self.log("accuracy", accuracy, prog_bar=True, on_step=True, on_epoch=True)
        self.train_accuracy.append(accuracy)

        loss = self.loss(logits, y)
        self.log("loss", loss, prog_bar=True, on_step=True, on_epoch=True)
        self.train_losses.append(loss.item())

        current_lr = self.optimizers().param_groups[0]["lr"]
        self.learning_rates.append(current_lr)

        return loss

    def validation_step(self, batch, batch_idx):
        self.val_steps.append(self.batch_step)
        x, y = batch

        logits = self.model(x)

        accuracy = self._accuracy(logits, y)
        self.log("val_accuracy", accuracy, prog_bar=True, on_step=True, on_epoch=True)
        self.val_accuracy.append(accuracy)

        loss = self.loss(logits, y)
        self.log("val_loss", loss, prog_bar=True, on_step=True, on_epoch=True)
        self.val_losses.append(loss.item())
        
        return loss

    def loss(self, output, expected):
        loss = nn.functional.cross_entropy(
            output.flatten(0, 1), expected.flatten()
        )
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(
            self.parameters(), lr=self.trainer_config["max_lr"], weight_decay=0.1
        )

        scheduler = OneCycleLR(
            optimizer,
            max_lr=self.trainer_config["max_lr"],
            total_steps=self.trainer.estimated_stepping_batches,
        )
        lr_scheduler_config = {
            "scheduler": scheduler,
            "interval": "step",
            "monitor": "loss"
        }

        return {
            "optimizer": optimizer,
            "lr_scheduler": lr_scheduler_config
        }

    def setup(self, stage):
        with open(self.trainer_config["train_file_loc"], encoding="utf-8") as f:
            self.train_text = f.read()

            text_len = len(self.train_text)
            dataset_scale = self.trainer_config["dataset_scale"]
            self.train_text = self.train_text[:text_len // dataset_scale]

        with open(self.trainer_config["valid_file_loc"], encoding="utf-8") as f:
            self.valid_text = f.read()

            # ensure validation set is not too long
            train_len = len(self.train_text)
            self.valid_text = self.valid_text[:train_len // 10]

        self.model = GPTModel_v2(self.gpt_config)
        if self.trainer_config["compile"]:
            self.model = torch.compile(self.model, fullgraph=True)
        
    def _create_dataloader(self, text, train_loader):
        return create_dataloader_v3(
            text,
            batch_size=self.trainer_config["batch_size"],
            max_length=self.gpt_config["context_length"],
            stride=self.gpt_config["context_length"],
            drop_last=train_loader,
            shuffle=train_loader,
            num_workers=self.trainer_config["num_workers"]
        )

    def train_dataloader(self):
        # consider setting self.train_text = None if memory consumption is an issue
        train_loader = self._create_dataloader(
            self.train_text,
            train_loader=True
        )
        return train_loader

    def val_dataloader(self):
        return self._create_dataloader(
            self.valid_text,
            train_loader=False
        )

# %%
litmodel = LitGPTModel(
    trainer_config,
    GPT_CONFIG
)

# %%
# %%time

trainer = L.Trainer(
    max_epochs=trainer_config["epochs"],
    enable_progress_bar=True,
    accumulate_grad_batches=trainer_config["grad_batches"]
)
trainer.fit(model=litmodel)
# Out:
# You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# 2025-04-02 01:54:21.261173: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-02 01:54:21.270560: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743584061.280599   10691 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743584061.283619   10691 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743584061.292081   10691 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743584061.292090   10691 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743584061.292091   10691 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743584061.292092   10691 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-02 01:54:21.294907: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading `train_dataloader` to estimate number of stepping batches.
#
#   | Name  | Type            | Params | Mode
# --------------------------------------------------
# 0 | model | OptimizedModule | 56.2 M | train
# --------------------------------------------------
# 56.2 M    Trainable params
# 0         Non-trainable params
# 56.2 M    Total params
# 224.768   Total estimated model params size (MB)
# 121       Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|███████████████████████| 56652/56652 [55:05<00:00, 17.14it/s, v_num=63, accuracy_step=0.865, loss_step=0.517]
# Validation: |                                                                                        | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                                                                 | 0/1727 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                    | 0/1727 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                            | 1/1727 [00:00<00:40, 42.17it/s]
# Validation DataLoader 0:   0%|                                                            | 2/1727 [00:00<00:36, 47.11it/s]
# Validation DataLoader 0:   0%|                                                            | 3/1727 [00:00<00:34, 49.58it/s]
# Validation DataLoader 0:   0%|▏                                                           | 4/1727 [00:00<00:33, 50.82it/s]
# Validation DataLoader 0:   0%|▏                                                           | 5/1727 [00:00<00:33, 51.48it/s]
# Validation DataLoader 0:   0%|▏                                                           | 6/1727 [00:00<00:33, 52.15it/s]
# Validation DataLoader 0:   0%|▏                                                           | 7/1727 [00:00<00:32, 52.57it/s]
# Validation DataLoader 0:   0%|▎                                                           | 8/1727 [00:00<00:32, 52.91it/s]
# Validation DataLoader 0:   1%|▎                                                           | 9/1727 [00:00<00:32, 53.05it/s]
# Validation DataLoader 0:   1%|▎                                                          | 10/1727 [00:00<00:32, 52.98it/s]
# Validation DataLoader 0:   1%|▍                                                          | 11/1727 [00:00<00:32, 53.14it/s]
# Validation DataLoader 0:   1%|▍                                                          | 12/1727 [00:00<00:32, 53.31it/s]
# Validation DataLoader 0:   1%|▍                                                          | 13/1727 [00:00<00:32, 53.41it/s]
# Validation DataLoader 0:   1%|▍                                                          | 14/1727 [00:00<00:31, 53.57it/s]
# Validation DataLoader 0:   1%|▌                                                          | 15/1727 [00:00<00:31, 53.65it/s]
# Validation DataLoader 0:   1%|▌                                                          | 16/1727 [00:00<00:31, 53.76it/s]
# Validation DataLoader 0:   1%|▌                                                          | 17/1727 [00:00<00:31, 53.57it/s]
# Validation DataLoader 0:   1%|▌                                                          | 18/1727 [00:00<00:31, 53.61it/s]
# Validation DataLoader 0:   1%|▋                                                          | 19/1727 [00:00<00:31, 53.58it/s]
# Validation DataLoader 0:   1%|▋                                                          | 20/1727 [00:00<00:31, 53.56it/s]
# Validation DataLoader 0:   1%|▋                                                          | 21/1727 [00:00<00:31, 53.64it/s]
# Validation DataLoader 0:   1%|▊                                                          | 22/1727 [00:00<00:31, 53.71it/s]
# Validation DataLoader 0:   1%|▊                                                          | 23/1727 [00:00<00:31, 53.81it/s]
# Validation DataLoader 0:   1%|▊                                                          | 24/1727 [00:00<00:31, 53.89it/s]
# Validation DataLoader 0:   1%|▊                                                          | 25/1727 [00:00<00:31, 53.96it/s]
# Validation DataLoader 0:   2%|▉                                                          | 26/1727 [00:00<00:31, 54.02it/s]
# Validation DataLoader 0:   2%|▉                                                          | 27/1727 [00:00<00:31, 54.09it/s]
# Validation DataLoader 0:   2%|▉                                                          | 28/1727 [00:00<00:31, 54.17it/s]
# Validation DataLoader 0:   2%|▉                                                          | 29/1727 [00:00<00:31, 54.22it/s]
# Validation DataLoader 0:   2%|█                                                          | 30/1727 [00:00<00:31, 54.27it/s]
# Validation DataLoader 0:   2%|█                                                          | 31/1727 [00:00<00:31, 54.30it/s]
# Validation DataLoader 0:   2%|█                                                          | 32/1727 [00:00<00:31, 54.35it/s]
# Validation DataLoader 0:   2%|█▏                                                         | 33/1727 [00:00<00:31, 54.39it/s]
# Validation DataLoader 0:   2%|█▏                                                         | 34/1727 [00:00<00:31, 54.40it/s]
# Validation DataLoader 0:   2%|█▏                                                         | 35/1727 [00:00<00:31, 54.38it/s]
# Validation DataLoader 0:   2%|█▏                                                         | 36/1727 [00:00<00:31, 54.35it/s]
# Validation DataLoader 0:   2%|█▎                                                         | 37/1727 [00:00<00:31, 54.38it/s]
# Validation DataLoader 0:   2%|█▎                                                         | 38/1727 [00:00<00:31, 54.41it/s]
# Validation DataLoader 0:   2%|█▎                                                         | 39/1727 [00:00<00:30, 54.45it/s]
# Validation DataLoader 0:   2%|█▎                                                         | 40/1727 [00:00<00:30, 54.43it/s]
# Validation DataLoader 0:   2%|█▍                                                         | 41/1727 [00:00<00:30, 54.47it/s]
# Validation DataLoader 0:   2%|█▍                                                         | 42/1727 [00:00<00:30, 54.46it/s]
# Validation DataLoader 0:   2%|█▍                                                         | 43/1727 [00:00<00:30, 54.47it/s]
# Validation DataLoader 0:   3%|█▌                                                         | 44/1727 [00:00<00:30, 54.50it/s]
# Validation DataLoader 0:   3%|█▌                                                         | 45/1727 [00:00<00:30, 54.52it/s]
# Validation DataLoader 0:   3%|█▌                                                         | 46/1727 [00:00<00:30, 54.54it/s]
# Validation DataLoader 0:   3%|█▌                                                         | 47/1727 [00:00<00:30, 54.57it/s]
# Validation DataLoader 0:   3%|█▋                                                         | 48/1727 [00:00<00:30, 54.61it/s]
# Validation DataLoader 0:   3%|█▋                                                         | 49/1727 [00:00<00:30, 54.64it/s]
# Validation DataLoader 0:   3%|█▋                                                         | 50/1727 [00:00<00:30, 54.66it/s]
# Validation DataLoader 0:   3%|█▋                                                         | 51/1727 [00:00<00:30, 54.69it/s]
# Validation DataLoader 0:   3%|█▊                                                         | 52/1727 [00:00<00:30, 54.73it/s]
# Validation DataLoader 0:   3%|█▊                                                         | 53/1727 [00:00<00:30, 54.75it/s]
# Validation DataLoader 0:   3%|█▊                                                         | 54/1727 [00:00<00:30, 54.77it/s]
# Validation DataLoader 0:   3%|█▉                                                         | 55/1727 [00:01<00:30, 54.76it/s]
# Validation DataLoader 0:   3%|█▉                                                         | 56/1727 [00:01<00:30, 54.76it/s]
# Validation DataLoader 0:   3%|█▉                                                         | 57/1727 [00:01<00:30, 54.78it/s]
# Validation DataLoader 0:   3%|█▉                                                         | 58/1727 [00:01<00:30, 54.75it/s]
# Validation DataLoader 0:   3%|██                                                         | 59/1727 [00:01<00:30, 54.75it/s]
# Validation DataLoader 0:   3%|██                                                         | 60/1727 [00:01<00:30, 54.75it/s]
# Validation DataLoader 0:   4%|██                                                         | 61/1727 [00:01<00:30, 54.78it/s]
# Validation DataLoader 0:   4%|██                                                         | 62/1727 [00:01<00:30, 54.81it/s]
# Validation DataLoader 0:   4%|██▏                                                        | 63/1727 [00:01<00:30, 54.83it/s]
# Validation DataLoader 0:   4%|██▏                                                        | 64/1727 [00:01<00:30, 54.84it/s]
# Validation DataLoader 0:   4%|██▏                                                        | 65/1727 [00:01<00:30, 54.81it/s]
# Validation DataLoader 0:   4%|██▎                                                        | 66/1727 [00:01<00:30, 54.81it/s]
# Validation DataLoader 0:   4%|██▎                                                        | 67/1727 [00:01<00:30, 54.82it/s]
# Validation DataLoader 0:   4%|██▎                                                        | 68/1727 [00:01<00:30, 54.84it/s]
# Validation DataLoader 0:   4%|██▎                                                        | 69/1727 [00:01<00:30, 54.86it/s]
# Validation DataLoader 0:   4%|██▍                                                        | 70/1727 [00:01<00:30, 54.86it/s]
# Validation DataLoader 0:   4%|██▍                                                        | 71/1727 [00:01<00:30, 54.88it/s]
# Validation DataLoader 0:   4%|██▍                                                        | 72/1727 [00:01<00:30, 54.91it/s]
# Validation DataLoader 0:   4%|██▍                                                        | 73/1727 [00:01<00:30, 54.93it/s]
# Validation DataLoader 0:   4%|██▌                                                        | 74/1727 [00:01<00:30, 54.94it/s]
# Validation DataLoader 0:   4%|██▌                                                        | 75/1727 [00:01<00:30, 54.95it/s]
# Validation DataLoader 0:   4%|██▌                                                        | 76/1727 [00:01<00:30, 54.94it/s]
# Validation DataLoader 0:   4%|██▋                                                        | 77/1727 [00:01<00:30, 54.94it/s]
# Validation DataLoader 0:   5%|██▋                                                        | 78/1727 [00:01<00:30, 54.96it/s]
# Validation DataLoader 0:   5%|██▋                                                        | 79/1727 [00:01<00:29, 54.98it/s]
# Validation DataLoader 0:   5%|██▋                                                        | 80/1727 [00:01<00:29, 54.99it/s]
# Validation DataLoader 0:   5%|██▊                                                        | 81/1727 [00:01<00:29, 55.00it/s]
# Validation DataLoader 0:   5%|██▊                                                        | 82/1727 [00:01<00:29, 55.02it/s]
# Validation DataLoader 0:   5%|██▊                                                        | 83/1727 [00:01<00:29, 55.03it/s]
# Validation DataLoader 0:   5%|██▊                                                        | 84/1727 [00:01<00:29, 55.05it/s]
# Validation DataLoader 0:   5%|██▉                                                        | 85/1727 [00:01<00:29, 55.07it/s]
# Validation DataLoader 0:   5%|██▉                                                        | 86/1727 [00:01<00:29, 55.08it/s]
# Validation DataLoader 0:   5%|██▉                                                        | 87/1727 [00:01<00:29, 55.09it/s]
# Validation DataLoader 0:   5%|███                                                        | 88/1727 [00:01<00:29, 55.10it/s]
# Validation DataLoader 0:   5%|███                                                        | 89/1727 [00:01<00:29, 55.10it/s]
# Validation DataLoader 0:   5%|███                                                        | 90/1727 [00:01<00:29, 55.11it/s]
# Validation DataLoader 0:   5%|███                                                        | 91/1727 [00:01<00:29, 55.12it/s]
# Validation DataLoader 0:   5%|███▏                                                       | 92/1727 [00:01<00:29, 55.12it/s]
# Validation DataLoader 0:   5%|███▏                                                       | 93/1727 [00:01<00:29, 55.13it/s]
# Validation DataLoader 0:   5%|███▏                                                       | 94/1727 [00:01<00:29, 55.13it/s]
# Validation DataLoader 0:   6%|███▏                                                       | 95/1727 [00:01<00:29, 55.15it/s]
# Validation DataLoader 0:   6%|███▎                                                       | 96/1727 [00:01<00:29, 55.16it/s]
# Validation DataLoader 0:   6%|███▎                                                       | 97/1727 [00:01<00:29, 55.16it/s]
# Validation DataLoader 0:   6%|███▎                                                       | 98/1727 [00:01<00:29, 55.17it/s]
# Validation DataLoader 0:   6%|███▍                                                       | 99/1727 [00:01<00:29, 55.19it/s]
# Validation DataLoader 0:   6%|███▎                                                      | 100/1727 [00:01<00:29, 55.20it/s]
# Validation DataLoader 0:   6%|███▍                                                      | 101/1727 [00:01<00:29, 55.21it/s]
# Validation DataLoader 0:   6%|███▍                                                      | 102/1727 [00:01<00:29, 55.22it/s]
# Validation DataLoader 0:   6%|███▍                                                      | 103/1727 [00:01<00:29, 55.24it/s]
# Validation DataLoader 0:   6%|███▍                                                      | 104/1727 [00:01<00:29, 55.25it/s]
# Validation DataLoader 0:   6%|███▌                                                      | 105/1727 [00:01<00:29, 55.24it/s]
# Validation DataLoader 0:   6%|███▌                                                      | 106/1727 [00:01<00:29, 55.25it/s]
# Validation DataLoader 0:   6%|███▌                                                      | 107/1727 [00:01<00:29, 55.25it/s]
# Validation DataLoader 0:   6%|███▋                                                      | 108/1727 [00:01<00:29, 55.25it/s]
# Validation DataLoader 0:   6%|███▋                                                      | 109/1727 [00:01<00:29, 55.26it/s]
# Validation DataLoader 0:   6%|███▋                                                      | 110/1727 [00:01<00:29, 55.27it/s]
# Validation DataLoader 0:   6%|███▋                                                      | 111/1727 [00:02<00:29, 55.28it/s]
# Validation DataLoader 0:   6%|███▊                                                      | 112/1727 [00:02<00:29, 55.28it/s]
# Validation DataLoader 0:   7%|███▊                                                      | 113/1727 [00:02<00:29, 55.28it/s]
# Validation DataLoader 0:   7%|███▊                                                      | 114/1727 [00:02<00:29, 55.28it/s]
# Validation DataLoader 0:   7%|███▊                                                      | 115/1727 [00:02<00:29, 55.29it/s]
# Validation DataLoader 0:   7%|███▉                                                      | 116/1727 [00:02<00:29, 55.30it/s]
# Validation DataLoader 0:   7%|███▉                                                      | 117/1727 [00:02<00:29, 55.32it/s]
# Validation DataLoader 0:   7%|███▉                                                      | 118/1727 [00:02<00:29, 55.32it/s]
# Validation DataLoader 0:   7%|███▉                                                      | 119/1727 [00:02<00:29, 55.32it/s]
# Validation DataLoader 0:   7%|████                                                      | 120/1727 [00:02<00:29, 55.33it/s]
# Validation DataLoader 0:   7%|████                                                      | 121/1727 [00:02<00:29, 55.34it/s]
# Validation DataLoader 0:   7%|████                                                      | 122/1727 [00:02<00:28, 55.35it/s]
# Validation DataLoader 0:   7%|████▏                                                     | 123/1727 [00:02<00:28, 55.35it/s]
# Validation DataLoader 0:   7%|████▏                                                     | 124/1727 [00:02<00:28, 55.35it/s]
# Validation DataLoader 0:   7%|████▏                                                     | 125/1727 [00:02<00:28, 55.36it/s]
# Validation DataLoader 0:   7%|████▏                                                     | 126/1727 [00:02<00:28, 55.36it/s]
# Validation DataLoader 0:   7%|████▎                                                     | 127/1727 [00:02<00:28, 55.37it/s]
# Validation DataLoader 0:   7%|████▎                                                     | 128/1727 [00:02<00:28, 55.38it/s]
# Validation DataLoader 0:   7%|████▎                                                     | 129/1727 [00:02<00:28, 55.39it/s]
# Validation DataLoader 0:   8%|████▎                                                     | 130/1727 [00:02<00:28, 55.39it/s]
# Validation DataLoader 0:   8%|████▍                                                     | 131/1727 [00:02<00:28, 55.40it/s]
# Validation DataLoader 0:   8%|████▍                                                     | 132/1727 [00:02<00:28, 55.41it/s]
# Validation DataLoader 0:   8%|████▍                                                     | 133/1727 [00:02<00:28, 55.41it/s]
# Validation DataLoader 0:   8%|████▌                                                     | 134/1727 [00:02<00:28, 55.42it/s]
# Validation DataLoader 0:   8%|████▌                                                     | 135/1727 [00:02<00:28, 55.42it/s]
# Validation DataLoader 0:   8%|████▌                                                     | 136/1727 [00:02<00:28, 55.43it/s]
# Validation DataLoader 0:   8%|████▌                                                     | 137/1727 [00:02<00:28, 55.44it/s]
# Validation DataLoader 0:   8%|████▋                                                     | 138/1727 [00:02<00:28, 55.44it/s]
# Validation DataLoader 0:   8%|████▋                                                     | 139/1727 [00:02<00:28, 55.44it/s]
# Validation DataLoader 0:   8%|████▋                                                     | 140/1727 [00:02<00:28, 55.45it/s]
# Validation DataLoader 0:   8%|████▋                                                     | 141/1727 [00:02<00:28, 55.46it/s]
# Validation DataLoader 0:   8%|████▊                                                     | 142/1727 [00:02<00:28, 55.46it/s]
# Validation DataLoader 0:   8%|████▊                                                     | 143/1727 [00:02<00:28, 55.45it/s]
# Validation DataLoader 0:   8%|████▊                                                     | 144/1727 [00:02<00:28, 55.45it/s]
# Validation DataLoader 0:   8%|████▊                                                     | 145/1727 [00:02<00:28, 55.46it/s]
# Validation DataLoader 0:   8%|████▉                                                     | 146/1727 [00:02<00:28, 55.46it/s]
# Validation DataLoader 0:   9%|████▉                                                     | 147/1727 [00:02<00:28, 55.46it/s]
# Validation DataLoader 0:   9%|████▉                                                     | 148/1727 [00:02<00:28, 55.47it/s]
# Validation DataLoader 0:   9%|█████                                                     | 149/1727 [00:02<00:28, 55.48it/s]
# Validation DataLoader 0:   9%|█████                                                     | 150/1727 [00:02<00:28, 55.48it/s]
# Validation DataLoader 0:   9%|█████                                                     | 151/1727 [00:02<00:28, 55.49it/s]
# Validation DataLoader 0:   9%|█████                                                     | 152/1727 [00:02<00:28, 55.50it/s]
# Validation DataLoader 0:   9%|█████▏                                                    | 153/1727 [00:02<00:28, 55.51it/s]
# Validation DataLoader 0:   9%|█████▏                                                    | 154/1727 [00:02<00:28, 55.51it/s]
# Validation DataLoader 0:   9%|█████▏                                                    | 155/1727 [00:02<00:28, 55.53it/s]
# Validation DataLoader 0:   9%|█████▏                                                    | 156/1727 [00:02<00:28, 55.53it/s]
# Validation DataLoader 0:   9%|█████▎                                                    | 157/1727 [00:02<00:28, 55.54it/s]
# Validation DataLoader 0:   9%|█████▎                                                    | 158/1727 [00:02<00:28, 55.54it/s]
# Validation DataLoader 0:   9%|█████▎                                                    | 159/1727 [00:02<00:28, 55.55it/s]
# Validation DataLoader 0:   9%|█████▎                                                    | 160/1727 [00:02<00:28, 55.55it/s]
# Validation DataLoader 0:   9%|█████▍                                                    | 161/1727 [00:02<00:28, 55.55it/s]
# Validation DataLoader 0:   9%|█████▍                                                    | 162/1727 [00:02<00:28, 55.56it/s]
# Validation DataLoader 0:   9%|█████▍                                                    | 163/1727 [00:02<00:28, 55.56it/s]
# Validation DataLoader 0:   9%|█████▌                                                    | 164/1727 [00:02<00:28, 55.56it/s]
# Validation DataLoader 0:  10%|█████▌                                                    | 165/1727 [00:02<00:28, 55.56it/s]
# Validation DataLoader 0:  10%|█████▌                                                    | 166/1727 [00:02<00:28, 55.57it/s]
# Validation DataLoader 0:  10%|█████▌                                                    | 167/1727 [00:03<00:28, 55.57it/s]
# Validation DataLoader 0:  10%|█████▋                                                    | 168/1727 [00:03<00:28, 55.57it/s]
# Validation DataLoader 0:  10%|█████▋                                                    | 169/1727 [00:03<00:28, 55.58it/s]
# Validation DataLoader 0:  10%|█████▋                                                    | 170/1727 [00:03<00:28, 55.58it/s]
# Validation DataLoader 0:  10%|█████▋                                                    | 171/1727 [00:03<00:27, 55.58it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 172/1727 [00:03<00:27, 55.58it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 173/1727 [00:03<00:27, 55.56it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 174/1727 [00:03<00:27, 55.55it/s]
# Validation DataLoader 0:  10%|█████▉                                                    | 175/1727 [00:03<00:27, 55.55it/s]
# Validation DataLoader 0:  10%|█████▉                                                    | 176/1727 [00:03<00:27, 55.55it/s]
# Validation DataLoader 0:  10%|█████▉                                                    | 177/1727 [00:03<00:27, 55.55it/s]
# Validation DataLoader 0:  10%|█████▉                                                    | 178/1727 [00:03<00:27, 55.56it/s]
# Validation DataLoader 0:  10%|██████                                                    | 179/1727 [00:03<00:27, 55.56it/s]
# Validation DataLoader 0:  10%|██████                                                    | 180/1727 [00:03<00:27, 55.57it/s]
# Validation DataLoader 0:  10%|██████                                                    | 181/1727 [00:03<00:27, 55.57it/s]
# Validation DataLoader 0:  11%|██████                                                    | 182/1727 [00:03<00:27, 55.58it/s]
# Validation DataLoader 0:  11%|██████▏                                                   | 183/1727 [00:03<00:27, 55.59it/s]
# Validation DataLoader 0:  11%|██████▏                                                   | 184/1727 [00:03<00:27, 55.59it/s]
# Validation DataLoader 0:  11%|██████▏                                                   | 185/1727 [00:03<00:27, 55.60it/s]
# Validation DataLoader 0:  11%|██████▏                                                   | 186/1727 [00:03<00:27, 55.60it/s]
# Validation DataLoader 0:  11%|██████▎                                                   | 187/1727 [00:03<00:27, 55.60it/s]
# Validation DataLoader 0:  11%|██████▎                                                   | 188/1727 [00:03<00:27, 55.61it/s]
# Validation DataLoader 0:  11%|██████▎                                                   | 189/1727 [00:03<00:27, 55.61it/s]
# Validation DataLoader 0:  11%|██████▍                                                   | 190/1727 [00:03<00:27, 55.61it/s]
# Validation DataLoader 0:  11%|██████▍                                                   | 191/1727 [00:03<00:27, 55.62it/s]
1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▏| 1702/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▏| 1703/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▏| 1704/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▎| 1705/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▎| 1706/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▎| 1707/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▎| 1708/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▍| 1709/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▍| 1710/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▍| 1711/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▌| 1712/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▌| 1713/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▌| 1714/1727 [00:30<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▌| 1715/1727 [00:31<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▋| 1716/1727 [00:31<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▋| 1717/1727 [00:31<00:00, 55.32it/s]
# Validation DataLoader 0:  99%|████████████████████████████████████████████████████████▋| 1718/1727 [00:31<00:00, 55.32it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████▋| 1719/1727 [00:31<00:00, 55.32it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████▊| 1720/1727 [00:31<00:00, 55.32it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████▊| 1721/1727 [00:31<00:00, 55.32it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████▊| 1722/1727 [00:31<00:00, 55.32it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████▊| 1723/1727 [00:31<00:00, 55.33it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████▉| 1724/1727 [00:31<00:00, 55.33it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████▉| 1725/1727 [00:31<00:00, 55.33it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████▉| 1726/1727 [00:31<00:00, 55.33it/s]
# Validation DataLoader 0: 100%|█████████████████████████████████████████████████████████| 1727/1727 [00:36<00:00, 47.17it/s]
# Epoch 0: 100%|█| 56652/56652 [55:42<00:00, 16.95it/s, v_num=63, accuracy_step=0.865, loss_step=0.517, val_accuracy_step=0.8
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|█| 56652/56652 [55:43<00:00, 16.95it/s, v_num=63, accuracy_step=0.865, loss_step=0.517, val_accuracy_step=0.8
# CPU times: user 55min 16s, sys: 1min 45s, total: 57min 1s
# Wall time: 55min 54s

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(litmodel.train_losses, label="Training Loss", color="blue")
ax1.scatter(litmodel.val_steps, litmodel.val_losses, label="Validation Loss", color="red")
ax1.set_xlabel("Training Step")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper left")

ax2 = ax1.twinx()
ax2.plot(litmodel.learning_rates, label="Learning Rate", color="green")
ax2.set_ylabel("Learning Rate")
ax2.legend(loc="upper right")

plt.title("Training/Validation Loss and Learning Rate")
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(litmodel.train_accuracy, color="blue")
plt.scatter(litmodel.val_steps, litmodel.val_accuracy, color="red")
plt.xlabel("Training Step")
plt.ylabel("Accuracy")
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# %%
from tokenizers import Tokenizer

# %%
tokenizer = Tokenizer.from_file("./TinyStories_tokenizer.json")

# %%
from tokenizers import decoders
tokenizer.decoder = decoders.WordPiece()

# %%
from components.generatetext import generate_text

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
litmodel.model.to(device)
# Out:
# OptimizedModule(
#   (_orig_mod): GPTModel_v2(
#     (tok_emb): Embedding(30002, 512)
#     (pos_emb): Embedding(512, 512)
#     (drop_emb): Dropout(p=0.0, inplace=False)
#     (trf_blocks): Sequential(
#       (0): TransformerBlock_v2(
#         (att): MultiHeadAttention_v2(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=512, bias=False)
#           (W_value): Linear(in_features=512, out_features=512, bias=False)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (ff): FeedForward(
#           (layers): Sequential(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#         )
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (drop_shortcut): Dropout(p=0.0, inplace=False)
#       )
#       (1): TransformerBlock_v2(
#         (att): MultiHeadAttention_v2(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=512, bias=False)
#           (W_value): Linear(in_features=512, out_features=512, bias=False)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (ff): FeedForward(
#           (layers): Sequential(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#         )
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (drop_shortcut): Dropout(p=0.0, inplace=False)
#       )
#       (2): TransformerBlock_v2(
#         (att): MultiHeadAttention_v2(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=512, bias=False)
#           (W_value): Linear(in_features=512, out_features=512, bias=False)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (ff): FeedForward(
#           (layers): Sequential(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#         )
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (drop_shortcut): Dropout(p=0.0, inplace=False)
#       )
#       (3): TransformerBlock_v2(
#         (att): MultiHeadAttention_v2(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=512, bias=False)
#           (W_value): Linear(in_features=512, out_features=512, bias=False)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (ff): FeedForward(
#           (layers): Sequential(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#         )
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (drop_shortcut): Dropout(p=0.0, inplace=False)
#       )
#       (4): TransformerBlock_v2(
#         (att): MultiHeadAttention_v2(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=512, bias=False)
#           (W_value): Linear(in_features=512, out_features=512, bias=False)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (ff): FeedForward(
#           (layers): Sequential(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#         )
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (drop_shortcut): Dropout(p=0.0, inplace=False)
#       )
#       (5): TransformerBlock_v2(
#         (att): MultiHeadAttention_v2(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=512, bias=False)
#           (W_value): Linear(in_features=512, out_features=512, bias=False)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (ff): FeedForward(
#           (layers): Sequential(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#         )
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (drop_shortcut): Dropout(p=0.0, inplace=False)
#       )
#       (6): TransformerBlock_v2(
#         (att): MultiHeadAttention_v2(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=512, bias=False)
#           (W_value): Linear(in_features=512, out_features=512, bias=False)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (ff): FeedForward(
#           (layers): Sequential(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#         )
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (drop_shortcut): Dropout(p=0.0, inplace=False)
#       )
#       (7): TransformerBlock_v2(
#         (att): MultiHeadAttention_v2(
#           (W_query): Linear(in_features=512, out_features=512, bias=False)
#           (W_key): Linear(in_features=512, out_features=512, bias=False)
#           (W_value): Linear(in_features=512, out_features=512, bias=False)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (ff): FeedForward(
#           (layers): Sequential(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#         )
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (drop_shortcut): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (final_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (out_head): Linear(in_features=512, out_features=30002, bias=False)
#     (seq_layers): Sequential(
#       (0): Dropout(p=0.0, inplace=False)
#       (1): Sequential(
#         (0): TransformerBlock_v2(
#           (att): MultiHeadAttention_v2(
#             (W_query): Linear(in_features=512, out_features=512, bias=False)
#             (W_key): Linear(in_features=512, out_features=512, bias=False)
#             (W_value): Linear(in_features=512, out_features=512, bias=False)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (ff): FeedForward(
#             (layers): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=2048, out_features=512, bias=True)
#             )
#           )
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (drop_shortcut): Dropout(p=0.0, inplace=False)
#         )
#         (1): TransformerBlock_v2(
#           (att): MultiHeadAttention_v2(
#             (W_query): Linear(in_features=512, out_features=512, bias=False)
#             (W_key): Linear(in_features=512, out_features=512, bias=False)
#             (W_value): Linear(in_features=512, out_features=512, bias=False)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (ff): FeedForward(
#             (layers): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=2048, out_features=512, bias=True)
#             )
#           )
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (drop_shortcut): Dropout(p=0.0, inplace=False)
#         )
#         (2): TransformerBlock_v2(
#           (att): MultiHeadAttention_v2(
#             (W_query): Linear(in_features=512, out_features=512, bias=False)
#             (W_key): Linear(in_features=512, out_features=512, bias=False)
#             (W_value): Linear(in_features=512, out_features=512, bias=False)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (ff): FeedForward(
#             (layers): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=2048, out_features=512, bias=True)
#             )
#           )
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (drop_shortcut): Dropout(p=0.0, inplace=False)
#         )
#         (3): TransformerBlock_v2(
#           (att): MultiHeadAttention_v2(
#             (W_query): Linear(in_features=512, out_features=512, bias=False)
#             (W_key): Linear(in_features=512, out_features=512, bias=False)
#             (W_value): Linear(in_features=512, out_features=512, bias=False)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (ff): FeedForward(
#             (layers): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=2048, out_features=512, bias=True)
#             )
#           )
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (drop_shortcut): Dropout(p=0.0, inplace=False)
#         )
#         (4): TransformerBlock_v2(
#           (att): MultiHeadAttention_v2(
#             (W_query): Linear(in_features=512, out_features=512, bias=False)
#             (W_key): Linear(in_features=512, out_features=512, bias=False)
#             (W_value): Linear(in_features=512, out_features=512, bias=False)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (ff): FeedForward(
#             (layers): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=2048, out_features=512, bias=True)
#             )
#           )
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (drop_shortcut): Dropout(p=0.0, inplace=False)
#         )
#         (5): TransformerBlock_v2(
#           (att): MultiHeadAttention_v2(
#             (W_query): Linear(in_features=512, out_features=512, bias=False)
#             (W_key): Linear(in_features=512, out_features=512, bias=False)
#             (W_value): Linear(in_features=512, out_features=512, bias=False)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (ff): FeedForward(
#             (layers): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=2048, out_features=512, bias=True)
#             )
#           )
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (drop_shortcut): Dropout(p=0.0, inplace=False)
#         )
#         (6): TransformerBlock_v2(
#           (att): MultiHeadAttention_v2(
#             (W_query): Linear(in_features=512, out_features=512, bias=False)
#             (W_key): Linear(in_features=512, out_features=512, bias=False)
#             (W_value): Linear(in_features=512, out_features=512, bias=False)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (ff): FeedForward(
#             (layers): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=2048, out_features=512, bias=True)
#             )
#           )
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (drop_shortcut): Dropout(p=0.0, inplace=False)
#         )
#         (7): TransformerBlock_v2(
#           (att): MultiHeadAttention_v2(
#             (W_query): Linear(in_features=512, out_features=512, bias=False)
#             (W_key): Linear(in_features=512, out_features=512, bias=False)
#             (W_value): Linear(in_features=512, out_features=512, bias=False)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (ff): FeedForward(
#             (layers): Sequential(
#               (0): Linear(in_features=512, out_features=2048, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=2048, out_features=512, bias=True)
#             )
#           )
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (drop_shortcut): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=30002, bias=False)
#     )
#   )
# )

# %%
# %%time
litmodel.eval()
starting_text = "Tom and Jane are friends. One day, Jane goes to Tom’s house. Tom has a big pot of soup. He wants to share it with Jane. “Jane, do you want some soup?” Tom asks. “Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is"
text = generate_text(litmodel.model, tokenizer, starting_text, 512, device, topk=3, temperature=1)
print("text: ", text)
# Out:
# text:  Tom and Jane are friends. One day, Jane goes to Tom ’ s house. Tom has a big pot of soup. He wants to share it with Jane. “ Jane, do you want some soup?” Tom asks. “ Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is still, the same way to share the rest of the rest of them. And they all. They both of their friendship. They are the best, and the same. They all. They all thanks to be friends. The moral of them, they were happy. The bad. The moral.
# CPU times: user 4.06 s, sys: 410 ms, total: 4.47 s
# Wall time: 4.34 s

# %%
# %%time
litmodel.eval()
starting_text = "Tom and Jane are friends. One day, Jane goes to Tom’s house. Tom has a big pot of soup. He wants to share it with Jane. “Jane, do you want some soup?” Tom asks. “Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is"
text = generate_text(litmodel.model, tokenizer, starting_text, 512, device, topk=3, temperature=1)
print("text: ", text)
# Out:
# text:  Tom and Jane are friends. One day, Jane goes to Tom ’ s house. Tom has a big pot of soup. He wants to share it with Jane. “ Jane, do you want some soup?” Tom asks. “ Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is not. They all that they all.
# CPU times: user 32.9 ms, sys: 0 ns, total: 32.9 ms
# Wall time: 30.3 ms

# %%
# %%time
litmodel.eval()
starting_text = "Tom and Jane are friends. One day, Jane goes to Tom’s house. Tom has a big pot of soup. He wants to share it with Jane. “Jane, do you want some soup?” Tom asks. “Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is"
text = generate_text(litmodel.model, tokenizer, starting_text, 512, device, topk=3, temperature=1)
print("text: ", text)
# Out:
# text:  Tom and Jane are friends. One day, Jane goes to Tom ’ s house. Tom has a big pot of soup. He wants to share it with Jane. “ Jane, do you want some soup?” Tom asks. “ Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is not as they are all. The two, Tom ' t, Tom, Tom, and Sue.
# CPU times: user 35.6 ms, sys: 10.5 ms, total: 46.1 ms
# Wall time: 43.1 ms

# %%
# %%time
litmodel.eval()
starting_text = "Tom and Jane are friends. One day, Jane goes to Tom’s house. Tom has a big pot of soup. He wants to share it with Jane. “Jane, do you want some soup?” Tom asks. “Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is"
text = generate_text(litmodel.model, tokenizer, starting_text, 512, device, topk=3, temperature=1)
print("text: ", text)
# Out:
# text:  Tom and Jane are friends. One day, Jane goes to Tom ’ s house. Tom has a big pot of soup. He wants to share it with Jane. “ Jane, do you want some soup?” Tom asks. “ Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is still.
# CPU times: user 10.6 ms, sys: 92 μs, total: 10.7 ms
# Wall time: 9.64 ms
