# %% [markdown]
# This script contains some improvement from train.ipynb by default:
# * much few layers, heads, and embedding dimension to reduce the model size
# * dataloader v2 which uses a custom tokenizer (again to reduce model size)
# * no positional embeddings (to reduce model complexity)
# * weight tying (to reduce model size)
#
#
# We implemented a few things here first and not before:
# * validation losses
# * increased the model size to be just below 30M parameters
# * reduced the amount of data trained with to keep the training (wall) time consistent
# * made graph more informative

# %% [markdown]
# This script contains a couple improvements from train2.ipynb:
# * gradient accumulation is enabled
# * the dataloader chunks from the start of an example up to the max_length or the endoftext token

# %% [markdown]
# This contains some changes from train3.ipynb:
# * an accuracy metric has been implemented
# * one cycle learning rate schedule is being used
# * weight tying is disabled

# %% [markdown]
# This contains some improvements from train4.ipynb: just that the attention module used uses pytorchs implementation for sdpa. This also uses a text generation function to display the capabilities of the trained model.

# %% [markdown]
# This contains some changes over train5.ipynb. We use data loading hooks for setting up the train/validation data loaders. We also use the setup hook for setting up the gpt model. We also call compile on the gpt model before training. We also have some code for investigating memory leaks.

# %%
import socket
socket.gethostname()
# Out:
# 'DESKTOP-ISTII7E'

# %%
GPT_CONFIG_30M = {
    "vocab_size": 30002,
    "context_length": 256,
    "emb_dim": 512,
    "n_heads": 4,
    "n_layers": 4,
    "drop_rate": 0.0,
    "qkv_bias": False,
    "weight_tying": True,
    "no_pos_emb": True
}

# %%
GPT_CONFIG_60M = {
    "vocab_size": 30002,
    "context_length": 512,
    "emb_dim": 512,
    "n_heads": 8,
    "n_layers": 8,
    "drop_rate": 0.0,
    "qkv_bias": False,
    "weight_tying": False,
    "no_pos_emb": True
}

# %%
import socket
hostname = socket.gethostname().lower()
if "laptop" in hostname:
    GPT_CONFIG = GPT_CONFIG_30M
else:
    GPT_CONFIG = GPT_CONFIG_60M

# %%
import torch.nn as nn
import torch

torch.set_float32_matmul_precision('medium')

# %%
trainer_config = {
    "dataset_scale": 1000,
    "batch_size": 32 if "laptop" in hostname else 16,
    "epochs": 1,
    "train_file_loc": "../data/TinyStories/TinyStoriesV2-GPT4-train.txt",
    "valid_file_loc": "../data/TinyStories/TinyStoriesV2-GPT4-valid.txt",
    "num_workers": 11 if "laptop" in hostname else 23,
    "max_lr": 1e-3,
    "compile": False#"laptop" not in hostname
}
trainer_config["grad_batches"] = 256 // trainer_config["batch_size"]

# %%
def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(
                input_batch, target_batch, model, device
            )
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(
            train_loader, model, device, num_batches=eval_iter
        )
        val_loss = calc_loss_loader(
            val_loader, model, device, num_batches=eval_iter
        )
    model.train()
    return train_loss, val_loss

# %%
def check_device(tensor, name):
    print(f"{name}: {tensor.device}")

def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch = input_batch.clone().detach().to(device)


    logits = model(input_batch)
    target_batch = target_batch.clone().detach().to(device)
    loss = nn.functional.cross_entropy(
        logits.flatten(0, 1), target_batch.flatten()
    )
    return loss

# %%
def train_model_simple(model, train_loader, val_loader,
                       optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1
    model.to(device)
    for epoch in range(num_epochs):
        model.train()
        for input_batch, target_batch in train_loader:
            optimizer.zero_grad()
            loss = calc_loss_batch(
                input_batch, target_batch, model, device
            )
            loss.backward()
            optimizer.step()
            tokens_seen += input_batch.numel()
            global_step += 1
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                    f"Train loss {train_loss:.3f}, "
                    f"Val loss {val_loss:.3f}"
                )
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )
    return train_losses, val_losses, track_tokens_seen

# %%
from components.gptmodel import GPTModel_v2
from torch.optim.lr_scheduler import OneCycleLR
from components.data import create_dataloader_v3
import lightning as L
import gc
import objgraph
from pympler import asizeof, muppy, summary
            

class LitGPTModel():
    def __init__(self, trainer_config, gpt_config):
        super().__init__()
        self.gpt_config = gpt_config
        self.trainer_config = trainer_config

        self.setup()
        

    def training_step(self, batch, batch_idx):
        if self.global_step % 100 == 0:
            gc.collect()
            # objgraph.show_most_common_types(limit=20)  

            # Get all objects in memory
            # all_objects = muppy.get_objects()            
            # Show top consumers
            # summary.print_(summary.summarize(all_objects), limit=10)

        x, y = batch
        logits = self.model(x)

        loss = self.loss(logits, y)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch

        logits = self.model(x)

        loss = self.loss(logits, y)
        
        return loss

    def loss(self, output, expected):
        loss = nn.functional.cross_entropy(
            output.flatten(0, 1), expected.flatten()
        )
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(
            self.model.parameters(), lr=self.trainer_config["max_lr"], weight_decay=0.1
        )
        return optimizer

    def setup(self):
        with open(self.trainer_config["train_file_loc"], encoding="utf-8") as f:
            self.train_text = f.read()

        text_len = len(self.train_text)
        dataset_scale = self.trainer_config["dataset_scale"]
        self.train_text = self.train_text[:text_len // dataset_scale]

        with open(self.trainer_config["valid_file_loc"], encoding="utf-8") as f:
            self.valid_text = f.read()

        # ensure validation set is not too long
        train_len = len(self.train_text)
        self.valid_text = self.valid_text[:train_len // 10]

        vocab_size = self.gpt_config["vocab_size"]
        emb_dim = self.gpt_config["emb_dim"]
        # self.model = nn.Linear(vocab_size, vocab_size)
        self.model = nn.Embedding(vocab_size, vocab_size)
        if self.trainer_config["compile"]:
            self.model = torch.compile(self.model, fullgraph=True)
        
    def _create_dataloader(self, text, train_loader):
        return create_dataloader_v3(
            text,
            batch_size=self.trainer_config["batch_size"],
            max_length=self.gpt_config["context_length"],
            stride=self.gpt_config["context_length"],
            drop_last=train_loader,
            shuffle=train_loader,
            num_workers=self.trainer_config["num_workers"]
        )

    def train_dataloader(self):
        # consider setting self.train_text = None if memory consumption is an issue
        train_loader = self._create_dataloader(
            self.train_text,
            train_loader=True
        )
        del self.train_text
        return train_loader

    def val_dataloader(self):
        return self._create_dataloader(
            self.valid_text,
            train_loader=False
        )

# %%
litmodel = LitGPTModel(
    trainer_config,
    GPT_CONFIG
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
litmodel.model.to(device)
# Out:
# Embedding(30002, 30002)

# %%
from tokenizers import Tokenizer

tokenizer = Tokenizer.from_file("./TinyStories_tokenizer.json")

# %%
train_model_simple(
    litmodel.model, litmodel.train_dataloader(), litmodel.val_dataloader(),
    litmodel.configure_optimizers(), device, trainer_config["epochs"],
    eval_freq=5, eval_iter=5, start_context="Once upon a time", tokenizer=tokenizer
)
# Out:
# Ep 1 (Step 000000): Train loss 10.946, Val loss 10.953
# Ep 1 (Step 000005): Train loss 10.940, Val loss 10.944
# Ep 1 (Step 000010): Train loss 10.935, Val loss 10.935
# Ep 1 (Step 000015): Train loss 10.920, Val loss 10.927
# Ep 1 (Step 000020): Train loss 10.932, Val loss 10.918
# Ep 1 (Step 000025): Train loss 10.914, Val loss 10.909
# Ep 1 (Step 000030): Train loss 10.891, Val loss 10.900
# Ep 1 (Step 000035): Train loss 10.894, Val loss 10.892
# Ep 1 (Step 000040): Train loss 10.876, Val loss 10.883
# Ep 1 (Step 000045): Train loss 10.878, Val loss 10.874
# Ep 1 (Step 000050): Train loss 10.864, Val loss 10.865
# Ep 1 (Step 000055): Train loss 10.854, Val loss 10.857
# Ep 1 (Step 000060): Train loss 10.849, Val loss 10.848
# Ep 1 (Step 000065): Train loss 10.844, Val loss 10.839
# Ep 1 (Step 000070): Train loss 10.830, Val loss 10.830
# Ep 1 (Step 000075): Train loss 10.826, Val loss 10.821
# Ep 1 (Step 000080): Train loss 10.812, Val loss 10.813
# Ep 1 (Step 000085): Train loss 10.802, Val loss 10.804
# Ep 1 (Step 000090): Train loss 10.793, Val loss 10.795
# Ep 1 (Step 000095): Train loss 10.789, Val loss 10.786
# Ep 1 (Step 000100): Train loss 10.781, Val loss 10.778
# Ep 1 (Step 000105): Train loss 10.763, Val loss 10.769
# Ep 1 (Step 000110): Train loss 10.756, Val loss 10.760
# Ep 1 (Step 000115): Train loss 10.751, Val loss 10.751
# Ep 1 (Step 000120): Train loss 10.746, Val loss 10.742
# Ep 1 (Step 000125): Train loss 10.736, Val loss 10.734
# Ep 1 (Step 000130): Train loss 10.722, Val loss 10.725
# Ep 1 (Step 000135): Train loss 10.703, Val loss 10.716
# Ep 1 (Step 000140): Train loss 10.703, Val loss 10.708
# Ep 1 (Step 000145): Train loss 10.701, Val loss 10.699
# Ep 1 (Step 000150): Train loss 10.691, Val loss 10.690
# Ep 1 (Step 000155): Train loss 10.679, Val loss 10.681
# Ep 1 (Step 000160): Train loss 10.672, Val loss 10.672
# Ep 1 (Step 000165): Train loss 10.657, Val loss 10.664
# Ep 1 (Step 000170): Train loss 10.652, Val loss 10.655
# Ep 1 (Step 000175): Train loss 10.639, Val loss 10.646
# Ep 1 (Step 000180): Train loss 10.629, Val loss 10.638
# Ep 1 (Step 000185): Train loss 10.629, Val loss 10.629
# Ep 1 (Step 000190): Train loss 10.620, Val loss 10.621
# Ep 1 (Step 000195): Train loss 10.612, Val loss 10.612
# Ep 1 (Step 000200): Train loss 10.609, Val loss 10.603
# Ep 1 (Step 000205): Train loss 10.589, Val loss 10.595
# Ep 1 (Step 000210): Train loss 10.581, Val loss 10.586
# Ep 1 (Step 000215): Train loss 10.569, Val loss 10.577
# Ep 1 (Step 000220): Train loss 10.567, Val loss 10.568
# Ep 1 (Step 000225): Train loss 10.562, Val loss 10.560
# Ep 1 (Step 000230): Train loss 10.549, Val loss 10.551
# Ep 1 (Step 000235): Train loss 10.537, Val loss 10.543
# Ep 1 (Step 000240): Train loss 10.534, Val loss 10.534
# Ep 1 (Step 000245): Train loss 10.525, Val loss 10.525
# Ep 1 (Step 000250): Train loss 10.511, Val loss 10.517
# Ep 1 (Step 000255): Train loss 10.507, Val loss 10.508
# Ep 1 (Step 000260): Train loss 10.495, Val loss 10.500
# Ep 1 (Step 000265): Train loss 10.493, Val loss 10.491
# Ep 1 (Step 000270): Train loss 10.479, Val loss 10.482
# Ep 1 (Step 000275): Train loss 10.469, Val loss 10.474
# Ep 1 (Step 000280): Train loss 10.458, Val loss 10.465
# Ep 1 (Step 000285): Train loss 10.446, Val loss 10.457
# Ep 1 (Step 000290): Train loss 10.448, Val loss 10.448
# Ep 1 (Step 000295): Train loss 10.437, Val loss 10.440
# Ep 1 (Step 000300): Train loss 10.428, Val loss 10.431
# Ep 1 (Step 000305): Train loss 10.416, Val loss 10.422
# Ep 1 (Step 000310): Train loss 10.409, Val loss 10.414
# Ep 1 (Step 000315): Train loss 10.403, Val loss 10.405
# Ep 1 (Step 000320): Train loss 10.392, Val loss 10.397
# Ep 1 (Step 000325): Train loss 10.381, Val loss 10.388
# Ep 1 (Step 000330): Train loss 10.371, Val loss 10.380
# Ep 1 (Step 000335): Train loss 10.364, Val loss 10.371
# Ep 1 (Step 000340): Train loss 10.359, Val loss 10.363
# Ep 1 (Step 000345): Train loss 10.346, Val loss 10.354
# Ep 1 (Step 000350): Train loss 10.339, Val loss 10.345
# Ep 1 (Step 000355): Train loss 10.335, Val loss 10.337
# Ep 1 (Step 000360): Train loss 10.323, Val loss 10.328
# Ep 1 (Step 000365): Train loss 10.318, Val loss 10.320
# Ep 1 (Step 000370): Train loss 10.313, Val loss 10.311
# Ep 1 (Step 000375): Train loss 10.301, Val loss 10.303
# Ep 1 (Step 000380): Train loss 10.289, Val loss 10.294
# Ep 1 (Step 000385): Train loss 10.278, Val loss 10.286
# Ep 1 (Step 000390): Train loss 10.266, Val loss 10.277
# Ep 1 (Step 000395): Train loss 10.267, Val loss 10.269
# Ep 1 (Step 000400): Train loss 10.259, Val loss 10.260
# Ep 1 (Step 000405): Train loss 10.242, Val loss 10.252
# Ep 1 (Step 000410): Train loss 10.235, Val loss 10.243
# Ep 1 (Step 000415): Train loss 10.226, Val loss 10.235
# Ep 1 (Step 000420): Train loss 10.216, Val loss 10.226
# Ep 1 (Step 000425): Train loss 10.205, Val loss 10.218
# Ep 1 (Step 000430): Train loss 10.198, Val loss 10.209
# Ep 1 (Step 000435): Train loss 10.201, Val loss 10.201
# Ep 1 (Step 000440): Train loss 10.188, Val loss 10.192
# Ep 1 (Step 000445): Train loss 10.176, Val loss 10.184
# Ep 1 (Step 000450): Train loss 10.165, Val loss 10.176
# Ep 1 (Step 000455): Train loss 10.165, Val loss 10.167
# Ep 1 (Step 000460): Train loss 10.146, Val loss 10.159
# Ep 1 (Step 000465): Train loss 10.142, Val loss 10.150
# Ep 1 (Step 000470): Train loss 10.136, Val loss 10.142
# Ep 1 (Step 000475): Train loss 10.124, Val loss 10.134
# Ep 1 (Step 000480): Train loss 10.116, Val loss 10.125
# Ep 1 (Step 000485): Train loss 10.105, Val loss 10.117
# Ep 1 (Step 000490): Train loss 10.096, Val loss 10.108
# Ep 1 (Step 000495): Train loss 10.087, Val loss 10.100
# Ep 1 (Step 000500): Train loss 10.074, Val loss 10.092
# Ep 1 (Step 000505): Train loss 10.068, Val loss 10.083
# Ep 1 (Step 000510): Train loss 10.064, Val loss 10.075
# Ep 1 (Step 000515): Train loss 10.056, Val loss 10.066
# Ep 1 (Step 000520): Train loss 10.048, Val loss 10.058
# Ep 1 (Step 000525): Train loss 10.041, Val loss 10.050
# Ep 1 (Step 000530): Train loss 10.023, Val loss 10.041
# Ep 1 (Step 000535): Train loss 10.016, Val loss 10.033
# Ep 1 (Step 000540): Train loss 10.020, Val loss 10.025
# Ep 1 (Step 000545): Train loss 9.994, Val loss 10.016
# Ep 1 (Step 000550): Train loss 9.997, Val loss 10.008
# Ep 1 (Step 000555): Train loss 9.994, Val loss 10.000
# Ep 1 (Step 000560): Train loss 9.982, Val loss 9.991
# Ep 1 (Step 000565): Train loss 9.970, Val loss 9.983
# Ep 1 (Step 000570): Train loss 9.974, Val loss 9.975
# Ep 1 (Step 000575): Train loss 9.955, Val loss 9.967
# Ep 1 (Step 000580): Train loss 9.947, Val loss 9.958
# Ep 1 (Step 000585): Train loss 9.944, Val loss 9.950
# Ep 1 (Step 000590): Train loss 9.936, Val loss 9.942
# Ep 1 (Step 000595): Train loss 9.920, Val loss 9.934
# Ep 1 (Step 000600): Train loss 9.917, Val loss 9.925
# Ep 1 (Step 000605): Train loss 9.901, Val loss 9.917
# Ep 1 (Step 000610): Train loss 9.897, Val loss 9.909
# Ep 1 (Step 000615): Train loss 9.887, Val loss 9.901
# Ep 1 (Step 000620): Train loss 9.879, Val loss 9.892
# Ep 1 (Step 000625): Train loss 9.877, Val loss 9.884
# Ep 1 (Step 000630): Train loss 9.870, Val loss 9.876
# Ep 1 (Step 000635): Train loss 9.854, Val loss 9.868
# Ep 1 (Step 000640): Train loss 9.851, Val loss 9.859
# Ep 1 (Step 000645): Train loss 9.843, Val loss 9.851
# Ep 1 (Step 000650): Train loss 9.830, Val loss 9.843
# Ep 1 (Step 000655): Train loss 9.820, Val loss 9.835
# Ep 1 (Step 000660): Train loss 9.812, Val loss 9.826
# Ep 1 (Step 000665): Train loss 9.811, Val loss 9.818
# Ep 1 (Step 000670): Train loss 9.806, Val loss 9.810
# Ep 1 (Step 000675): Train loss 9.788, Val loss 9.802
# Ep 1 (Step 000680): Train loss 9.785, Val loss 9.794
# Ep 1 (Step 000685): Train loss 9.773, Val loss 9.785
# Ep 1 (Step 000690): Train loss 9.762, Val loss 9.777
# Ep 1 (Step 000695): Train loss 9.764, Val loss 9.769
# Ep 1 (Step 000700): Train loss 9.754, Val loss 9.761
# Ep 1 (Step 000705): Train loss 9.734, Val loss 9.753
# Ep 1 (Step 000710): Train loss 9.734, Val loss 9.744
# Ep 1 (Step 000715): Train loss 9.715, Val loss 9.736
# Ep 1 (Step 000720): Train loss 9.718, Val loss 9.728
# Ep 1 (Step 000725): Train loss 9.722, Val loss 9.720
# Ep 1 (Step 000730): Train loss 9.701, Val loss 9.712
# Ep 1 (Step 000735): Train loss 9.685, Val loss 9.704
# Ep 1 (Step 000740): Train loss 9.670, Val loss 9.696
# Ep 1 (Step 000745): Train loss 9.671, Val loss 9.688
# Ep 1 (Step 000750): Train loss 9.666, Val loss 9.679
# Ep 1 (Step 000755): Train loss 9.656, Val loss 9.671
# Ep 1 (Step 000760): Train loss 9.645, Val loss 9.663
# Ep 1 (Step 000765): Train loss 9.657, Val loss 9.655
# Ep 1 (Step 000770): Train loss 9.655, Val loss 9.647
# Ep 1 (Step 000775): Train loss 9.622, Val loss 9.639
# Ep 1 (Step 000780): Train loss 9.600, Val loss 9.631
# Ep 1 (Step 000785): Train loss 9.603, Val loss 9.622
# Ep 1 (Step 000790): Train loss 9.611, Val loss 9.614
# Ep 1 (Step 000795): Train loss 9.582, Val loss 9.606
# Ep 1 (Step 000800): Train loss 9.569, Val loss 9.598
# Ep 1 (Step 000805): Train loss 9.566, Val loss 9.590
# Ep 1 (Step 000810): Train loss 9.571, Val loss 9.582
# Ep 1 (Step 000815): Train loss 9.570, Val loss 9.574
# Ep 1 (Step 000820): Train loss 9.546, Val loss 9.566
# Ep 1 (Step 000825): Train loss 9.539, Val loss 9.557
# Ep 1 (Step 000830): Train loss 9.532, Val loss 9.549
# Ep 1 (Step 000835): Train loss 9.534, Val loss 9.541
# Ep 1 (Step 000840): Train loss 9.516, Val loss 9.533
# Ep 1 (Step 000845): Train loss 9.511, Val loss 9.525
# Ep 1 (Step 000850): Train loss 9.501, Val loss 9.517
# Ep 1 (Step 000855): Train loss 9.523, Val loss 9.509
# Ep 1 (Step 000860): Train loss 9.474, Val loss 9.501
# Ep 1 (Step 000865): Train loss 9.467, Val loss 9.493
# Ep 1 (Step 000870): Train loss 9.456, Val loss 9.485
# Ep 1 (Step 000875): Train loss 9.459, Val loss 9.477
# Ep 1 (Step 000880): Train loss 9.444, Val loss 9.469
# Ep 1 (Step 000885): Train loss 9.435, Val loss 9.461
# Ep 1 (Step 000890): Train loss 9.432, Val loss 9.453
# Ep 1 (Step 000895): Train loss 9.420, Val loss 9.445
# Ep 1 (Step 000900): Train loss 9.423, Val loss 9.437
# Ep 1 (Step 000905): Train loss 9.427, Val loss 9.429
# Ep 1 (Step 000910): Train loss 9.402, Val loss 9.421
# Ep 1 (Step 000915): Train loss 9.413, Val loss 9.412
# Ep 1 (Step 000920): Train loss 9.405, Val loss 9.405
# Ep 1 (Step 000925): Train loss 9.380, Val loss 9.396
# Ep 1 (Step 000930): Train loss 9.372, Val loss 9.389
# Ep 1 (Step 000935): Train loss 9.373, Val loss 9.380
# Ep 1 (Step 000940): Train loss 9.362, Val loss 9.373
# Ep 1 (Step 000945): Train loss 9.340, Val loss 9.365
# Ep 1 (Step 000950): Train loss 9.339, Val loss 9.357
# Ep 1 (Step 000955): Train loss 9.338, Val loss 9.349
# Ep 1 (Step 000960): Train loss 9.337, Val loss 9.341
# Ep 1 (Step 000965): Train loss 9.323, Val loss 9.333
# Ep 1 (Step 000970): Train loss 9.311, Val loss 9.325
# Ep 1 (Step 000975): Train loss 9.294, Val loss 9.317
# Ep 1 (Step 000980): Train loss 9.303, Val loss 9.309
# Ep 1 (Step 000985): Train loss 9.291, Val loss 9.301
# Ep 1 (Step 000990): Train loss 9.273, Val loss 9.293
# Ep 1 (Step 000995): Train loss 9.261, Val loss 9.285
# Ep 1 (Step 001000): Train loss 9.256, Val loss 9.277
# Ep 1 (Step 001005): Train loss 9.239, Val loss 9.270
# Ep 1 (Step 001010): Train loss 9.239, Val loss 9.262
# Ep 1 (Step 001015): Train loss 9.215, Val loss 9.254
# Ep 1 (Step 001020): Train loss 9.231, Val loss 9.246
# Ep 1 (Step 001025): Train loss 9.237, Val loss 9.238
# Ep 1 (Step 001030): Train loss 9.208, Val loss 9.230
# Ep 1 (Step 001035): Train loss 9.188, Val loss 9.223
# Ep 1 (Step 001040): Train loss 9.199, Val loss 9.215
# Ep 1 (Step 001045): Train loss 9.195, Val loss 9.207
# Ep 1 (Step 001050): Train loss 9.169, Val loss 9.199
# Ep 1 (Step 001055): Train loss 9.161, Val loss 9.191
# Ep 1 (Step 001060): Train loss 9.145, Val loss 9.183
# Ep 1 (Step 001065): Train loss 9.148, Val loss 9.176
# Ep 1 (Step 001070): Train loss 9.165, Val loss 9.168
# Ep 1 (Step 001075): Train loss 9.145, Val loss 9.160
# Ep 1 (Step 001080): Train loss 9.139, Val loss 9.152
# Ep 1 (Step 001085): Train loss 9.136, Val loss 9.144
# Ep 1 (Step 001090): Train loss 9.145, Val loss 9.136
# Ep 1 (Step 001095): Train loss 9.114, Val loss 9.128
# Ep 1 (Step 001100): Train loss 9.104, Val loss 9.120
# Ep 1 (Step 001105): Train loss 9.114, Val loss 9.113
# Ep 1 (Step 001110): Train loss 9.052, Val loss 9.105
# Ep 1 (Step 001115): Train loss 9.079, Val loss 9.097
# Ep 1 (Step 001120): Train loss 9.059, Val loss 9.089
# Ep 1 (Step 001125): Train loss 9.070, Val loss 9.081
# Ep 1 (Step 001130): Train loss 9.046, Val loss 9.074
# Ep 1 (Step 001135): Train loss 9.028, Val loss 9.066
# Ep 1 (Step 001140): Train loss 9.016, Val loss 9.058
# Ep 1 (Step 001145): Train loss 9.022, Val loss 9.050
# Ep 1 (Step 001150): Train loss 8.993, Val loss 9.042
# Ep 1 (Step 001155): Train loss 9.014, Val loss 9.035
# Ep 1 (Step 001160): Train loss 9.000, Val loss 9.027
# Ep 1 (Step 001165): Train loss 9.004, Val loss 9.019
# Ep 1 (Step 001170): Train loss 8.956, Val loss 9.011
# Ep 1 (Step 001175): Train loss 8.990, Val loss 9.004
# Ep 1 (Step 001180): Train loss 8.980, Val loss 8.996
# Ep 1 (Step 001185): Train loss 8.943, Val loss 8.988
# Ep 1 (Step 001190): Train loss 8.934, Val loss 8.981
# Ep 1 (Step 001195): Train loss 8.977, Val loss 8.973
# Ep 1 (Step 001200): Train loss 8.910, Val loss 8.965
# Ep 1 (Step 001205): Train loss 8.921, Val loss 8.957
# Ep 1 (Step 001210): Train loss 8.930, Val loss 8.950
# Ep 1 (Step 001215): Train loss 8.908, Val loss 8.942
# Ep 1 (Step 001220): Train loss 8.917, Val loss 8.934
# Ep 1 (Step 001225): Train loss 8.882, Val loss 8.927
# Ep 1 (Step 001230): Train loss 8.903, Val loss 8.919
# Ep 1 (Step 001235): Train loss 8.873, Val loss 8.911
# Ep 1 (Step 001240): Train loss 8.887, Val loss 8.903
# Ep 1 (Step 001245): Train loss 8.878, Val loss 8.896
# Ep 1 (Step 001250): Train loss 8.857, Val loss 8.888
# Ep 1 (Step 001255): Train loss 8.838, Val loss 8.881
# Ep 1 (Step 001260): Train loss 8.828, Val loss 8.873
# Ep 1 (Step 001265): Train loss 8.815, Val loss 8.865
# Ep 1 (Step 001270): Train loss 8.820, Val loss 8.858
# Ep 1 (Step 001275): Train loss 8.816, Val loss 8.850
# Ep 1 (Step 001280): Train loss 8.845, Val loss 8.842
# Ep 1 (Step 001285): Train loss 8.805, Val loss 8.835
# Ep 1 (Step 001290): Train loss 8.792, Val loss 8.827
# Ep 1 (Step 001295): Train loss 8.803, Val loss 8.819
# Ep 1 (Step 001300): Train loss 8.791, Val loss 8.811
# Ep 1 (Step 001305): Train loss 8.772, Val loss 8.804
# Ep 1 (Step 001310): Train loss 8.784, Val loss 8.796
# Ep 1 (Step 001315): Train loss 8.766, Val loss 8.788
# Ep 1 (Step 001320): Train loss 8.715, Val loss 8.781
# Ep 1 (Step 001325): Train loss 8.768, Val loss 8.773
# Ep 1 (Step 001330): Train loss 8.737, Val loss 8.765
# Ep 1 (Step 001335): Train loss 8.717, Val loss 8.758
# Ep 1 (Step 001340): Train loss 8.715, Val loss 8.750
# Ep 1 (Step 001345): Train loss 8.705, Val loss 8.742
# Ep 1 (Step 001350): Train loss 8.734, Val loss 8.735
# Ep 1 (Step 001355): Train loss 8.693, Val loss 8.727
# Ep 1 (Step 001360): Train loss 8.675, Val loss 8.720
# Ep 1 (Step 001365): Train loss 8.706, Val loss 8.712
# Ep 1 (Step 001370): Train loss 8.677, Val loss 8.704
# Ep 1 (Step 001375): Train loss 8.678, Val loss 8.697
# Ep 1 (Step 001380): Train loss 8.656, Val loss 8.689
# Ep 1 (Step 001385): Train loss 8.637, Val loss 8.682
# Ep 1 (Step 001390): Train loss 8.661, Val loss 8.674
# Ep 1 (Step 001395): Train loss 8.630, Val loss 8.667
# Ep 1 (Step 001400): Train loss 8.631, Val loss 8.659
# Ep 1 (Step 001405): Train loss 8.622, Val loss 8.652
# Ep 1 (Step 001410): Train loss 8.635, Val loss 8.644
# Ep 1 (Step 001415): Train loss 8.625, Val loss 8.637
# Ep 1 (Step 001420): Train loss 8.582, Val loss 8.629
# Ep 1 (Step 001425): Train loss 8.582, Val loss 8.622
# Ep 1 (Step 001430): Train loss 8.579, Val loss 8.614
# Ep 1 (Step 001435): Train loss 8.604, Val loss 8.607
# Ep 1 (Step 001440): Train loss 8.557, Val loss 8.599
# Ep 1 (Step 001445): Train loss 8.539, Val loss 8.592
# Ep 1 (Step 001450): Train loss 8.553, Val loss 8.584
# Ep 1 (Step 001455): Train loss 8.543, Val loss 8.577
# Ep 1 (Step 001460): Train loss 8.561, Val loss 8.569
# Ep 1 (Step 001465): Train loss 8.504, Val loss 8.562
# Ep 1 (Step 001470): Train loss 8.502, Val loss 8.554
# Ep 1 (Step 001475): Train loss 8.518, Val loss 8.547
# Ep 1 (Step 001480): Train loss 8.516, Val loss 8.539
# Ep 1 (Step 001485): Train loss 8.509, Val loss 8.532
# Ep 1 (Step 001490): Train loss 8.471, Val loss 8.524
# Ep 1 (Step 001495): Train loss 8.501, Val loss 8.517
# Ep 1 (Step 001500): Train loss 8.500, Val loss 8.509
# Ep 1 (Step 001505): Train loss 8.445, Val loss 8.502
# Ep 1 (Step 001510): Train loss 8.456, Val loss 8.494
# Ep 1 (Step 001515): Train loss 8.463, Val loss 8.487
# Ep 1 (Step 001520): Train loss 8.454, Val loss 8.479
# Ep 1 (Step 001525): Train loss 8.431, Val loss 8.472
# Ep 1 (Step 001530): Train loss 8.445, Val loss 8.465
# Ep 1 (Step 001535): Train loss 8.477, Val loss 8.457
# Ep 1 (Step 001540): Train loss 8.453, Val loss 8.450
# Ep 1 (Step 001545): Train loss 8.376, Val loss 8.442
# Ep 1 (Step 001550): Train loss 8.403, Val loss 8.435
# Ep 1 (Step 001555): Train loss 8.402, Val loss 8.428
# Ep 1 (Step 001560): Train loss 8.369, Val loss 8.420
# Ep 1 (Step 001565): Train loss 8.393, Val loss 8.413
# Ep 1 (Step 001570): Train loss 8.341, Val loss 8.406
# Ep 1 (Step 001575): Train loss 8.374, Val loss 8.398
# Ep 1 (Step 001580): Train loss 8.351, Val loss 8.391
# Ep 1 (Step 001585): Train loss 8.308, Val loss 8.383
# Ep 1 (Step 001590): Train loss 8.334, Val loss 8.376
# Ep 1 (Step 001595): Train loss 8.333, Val loss 8.369
# Ep 1 (Step 001600): Train loss 8.333, Val loss 8.361
# Ep 1 (Step 001605): Train loss 8.307, Val loss 8.354
# Ep 1 (Step 001610): Train loss 8.323, Val loss 8.347
# Ep 1 (Step 001615): Train loss 8.302, Val loss 8.339
# Ep 1 (Step 001620): Train loss 8.301, Val loss 8.332
# Ep 1 (Step 001625): Train loss 8.289, Val loss 8.324
# Ep 1 (Step 001630): Train loss 8.327, Val loss 8.317
# Ep 1 (Step 001635): Train loss 8.276, Val loss 8.310
# Ep 1 (Step 001640): Train loss 8.254, Val loss 8.302
# Ep 1 (Step 001645): Train loss 8.229, Val loss 8.295
# Ep 1 (Step 001650): Train loss 8.265, Val loss 8.288
# Ep 1 (Step 001655): Train loss 8.285, Val loss 8.280
# Ep 1 (Step 001660): Train loss 8.255, Val loss 8.273
# Ep 1 (Step 001665): Train loss 8.248, Val loss 8.266
# Ep 1 (Step 001670): Train loss 8.227, Val loss 8.258
# Ep 1 (Step 001675): Train loss 8.235, Val loss 8.251
# Ep 1 (Step 001680): Train loss 8.187, Val loss 8.244
# Ep 1 (Step 001685): Train loss 8.181, Val loss 8.236
# Ep 1 (Step 001690): Train loss 8.188, Val loss 8.229
# Ep 1 (Step 001695): Train loss 8.192, Val loss 8.222
# Ep 1 (Step 001700): Train loss 8.180, Val loss 8.214
# Ep 1 (Step 001705): Train loss 8.151, Val loss 8.207
# Ep 1 (Step 001710): Train loss 8.174, Val loss 8.200
# Ep 1 (Step 001715): Train loss 8.157, Val loss 8.193
# Ep 1 (Step 001720): Train loss 8.133, Val loss 8.185
# Ep 1 (Step 001725): Train loss 8.147, Val loss 8.178
# Ep 1 (Step 001730): Train loss 8.151, Val loss 8.171
# Ep 1 (Step 001735): Train loss 8.155, Val loss 8.164
# Ep 1 (Step 001740): Train loss 8.154, Val loss 8.156
# Ep 1 (Step 001745): Train loss 8.114, Val loss 8.149
# Ep 1 (Step 001750): Train loss 8.115, Val loss 8.142
# Ep 1 (Step 001755): Train loss 8.091, Val loss 8.135
# Ep 1 (Step 001760): Train loss 8.087, Val loss 8.127
# Ep 1 (Step 001765): Train loss 8.127, Val loss 8.120
# Ep 1 (Step 001770): Train loss 8.066, Val loss 8.113
# Ep 1 (Step 001775): Train loss 8.062, Val loss 8.106
# Ep 1 (Step 001780): Train loss 8.081, Val loss 8.098
# Ep 1 (Step 001785): Train loss 8.039, Val loss 8.091
# Ep 1 (Step 001790): Train loss 8.036, Val loss 8.084
# Ep 1 (Step 001795): Train loss 8.054, Val loss 8.077
# Ep 1 (Step 001800): Train loss 8.040, Val loss 8.070
# Ep 1 (Step 001805): Train loss 7.991, Val loss 8.062
# Ep 1 (Step 001810): Train loss 8.027, Val loss 8.055
# Ep 1 (Step 001815): Train loss 8.035, Val loss 8.048
# Ep 1 (Step 001820): Train loss 8.032, Val loss 8.041
# Ep 1 (Step 001825): Train loss 8.027, Val loss 8.034
# Ep 1 (Step 001830): Train loss 8.056, Val loss 8.027
# Ep 1 (Step 001835): Train loss 7.979, Val loss 8.019
# Ep 1 (Step 001840): Train loss 7.975, Val loss 8.012
# Ep 1 (Step 001845): Train loss 7.947, Val loss 8.005
# Ep 1 (Step 001850): Train loss 7.963, Val loss 7.998
# Ep 1 (Step 001855): Train loss 7.972, Val loss 7.991
# Ep 1 (Step 001860): Train loss 7.965, Val loss 7.984
# Ep 1 (Step 001865): Train loss 7.931, Val loss 7.977
# Ep 1 (Step 001870): Train loss 7.936, Val loss 7.969
# Ep 1 (Step 001875): Train loss 7.961, Val loss 7.962
# Ep 1 (Step 001880): Train loss 7.916, Val loss 7.955
# Ep 1 (Step 001885): Train loss 7.948, Val loss 7.948
# Ep 1 (Step 001890): Train loss 7.894, Val loss 7.941
# Ep 1 (Step 001895): Train loss 7.908, Val loss 7.934
# Ep 1 (Step 001900): Train loss 7.898, Val loss 7.927
# Ep 1 (Step 001905): Train loss 7.881, Val loss 7.920
# Ep 1 (Step 001910): Train loss 7.919, Val loss 7.913
# Ep 1 (Step 001915): Train loss 7.861, Val loss 7.906
# Ep 1 (Step 001920): Train loss 7.901, Val loss 7.898
# Ep 1 (Step 001925): Train loss 7.867, Val loss 7.891
# Ep 1 (Step 001930): Train loss 7.842, Val loss 7.884
# Ep 1 (Step 001935): Train loss 7.869, Val loss 7.877
# Ep 1 (Step 001940): Train loss 7.815, Val loss 7.870
# Ep 1 (Step 001945): Train loss 7.792, Val loss 7.863
# Ep 1 (Step 001950): Train loss 7.847, Val loss 7.856
# Ep 1 (Step 001955): Train loss 7.800, Val loss 7.849
# Ep 1 (Step 001960): Train loss 7.778, Val loss 7.842
# Ep 1 (Step 001965): Train loss 7.816, Val loss 7.835
# Ep 1 (Step 001970): Train loss 7.812, Val loss 7.828
# Ep 1 (Step 001975): Train loss 7.755, Val loss 7.821
# Ep 1 (Step 001980): Train loss 7.796, Val loss 7.814
# Ep 1 (Step 001985): Train loss 7.781, Val loss 7.807
# Ep 1 (Step 001990): Train loss 7.785, Val loss 7.800
# Ep 1 (Step 001995): Train loss 7.773, Val loss 7.793
# Ep 1 (Step 002000): Train loss 7.774, Val loss 7.785
# Ep 1 (Step 002005): Train loss 7.747, Val loss 7.778
# Ep 1 (Step 002010): Train loss 7.767, Val loss 7.771
# Ep 1 (Step 002015): Train loss 7.689, Val loss 7.764
# Ep 1 (Step 002020): Train loss 7.700, Val loss 7.758
# Ep 1 (Step 002025): Train loss 7.737, Val loss 7.751
# Ep 1 (Step 002030): Train loss 7.701, Val loss 7.744
# Ep 1 (Step 002035): Train loss 7.708, Val loss 7.737
# Ep 1 (Step 002040): Train loss 7.652, Val loss 7.730
# Ep 1 (Step 002045): Train loss 7.630, Val loss 7.723
# Ep 1 (Step 002050): Train loss 7.691, Val loss 7.716
# Ep 1 (Step 002055): Train loss 7.690, Val loss 7.709
# Ep 1 (Step 002060): Train loss 7.652, Val loss 7.702
# Ep 1 (Step 002065): Train loss 7.673, Val loss 7.695
# Ep 1 (Step 002070): Train loss 7.594, Val loss 7.688
# Ep 1 (Step 002075): Train loss 7.633, Val loss 7.681
# Ep 1 (Step 002080): Train loss 7.639, Val loss 7.674
# Ep 1 (Step 002085): Train loss 7.594, Val loss 7.667
# Ep 1 (Step 002090): Train loss 7.593, Val loss 7.660
# Ep 1 (Step 002095): Train loss 7.603, Val loss 7.653
# Ep 1 (Step 002100): Train loss 7.652, Val loss 7.646
# Ep 1 (Step 002105): Train loss 7.602, Val loss 7.640
# Ep 1 (Step 002110): Train loss 7.596, Val loss 7.633
# Ep 1 (Step 002115): Train loss 7.572, Val loss 7.626
# Ep 1 (Step 002120): Train loss 7.575, Val loss 7.619
# Ep 1 (Step 002125): Train loss 7.610, Val loss 7.612
# Ep 1 (Step 002130): Train loss 7.508, Val loss 7.605
# Ep 1 (Step 002135): Train loss 7.543, Val loss 7.598
# Ep 1 (Step 002140): Train loss 7.586, Val loss 7.591
# Ep 1 (Step 002145): Train loss 7.567, Val loss 7.584
# Ep 1 (Step 002150): Train loss 7.548, Val loss 7.577
# Ep 1 (Step 002155): Train loss 7.556, Val loss 7.570
# Ep 1 (Step 002160): Train loss 7.564, Val loss 7.564
# Ep 1 (Step 002165): Train loss 7.572, Val loss 7.557
# Ep 1 (Step 002170): Train loss 7.569, Val loss 7.550
# Ep 1 (Step 002175): Train loss 7.479, Val loss 7.543
# Ep 1 (Step 002180): Train loss 7.531, Val loss 7.536
# Ep 1 (Step 002185): Train loss 7.483, Val loss 7.529
# Ep 1 (Step 002190): Train loss 7.429, Val loss 7.522
# Ep 1 (Step 002195): Train loss 7.499, Val loss 7.516
# Ep 1 (Step 002200): Train loss 7.502, Val loss 7.509
# Ep 1 (Step 002205): Train loss 7.452, Val loss 7.502
# Ep 1 (Step 002210): Train loss 7.476, Val loss 7.495
# Ep 1 (Step 002215): Train loss 7.493, Val loss 7.488
# Ep 1 (Step 002220): Train loss 7.493, Val loss 7.481
# Ep 1 (Step 002225): Train loss 7.384, Val loss 7.474
# Ep 1 (Step 002230): Train loss 7.417, Val loss 7.468
# Ep 1 (Step 002235): Train loss 7.442, Val loss 7.461
# Ep 1 (Step 002240): Train loss 7.372, Val loss 7.454
# Ep 1 (Step 002245): Train loss 7.420, Val loss 7.447
# Ep 1 (Step 002250): Train loss 7.371, Val loss 7.441
# Ep 1 (Step 002255): Train loss 7.370, Val loss 7.434
# Ep 1 (Step 002260): Train loss 7.362, Val loss 7.427
# Ep 1 (Step 002265): Train loss 7.372, Val loss 7.420
# Ep 1 (Step 002270): Train loss 7.376, Val loss 7.413
# Ep 1 (Step 002275): Train loss 7.466, Val loss 7.407
# Ep 1 (Step 002280): Train loss 7.415, Val loss 7.400
# Ep 1 (Step 002285): Train loss 7.331, Val loss 7.393
# Ep 1 (Step 002290): Train loss 7.344, Val loss 7.386
# Ep 1 (Step 002295): Train loss 7.329, Val loss 7.379
# Ep 1 (Step 002300): Train loss 7.292, Val loss 7.373
# Ep 1 (Step 002305): Train loss 7.286, Val loss 7.366
# Ep 1 (Step 002310): Train loss 7.296, Val loss 7.359
# Ep 1 (Step 002315): Train loss 7.274, Val loss 7.352
# Ep 1 (Step 002320): Train loss 7.324, Val loss 7.346
# Ep 1 (Step 002325): Train loss 7.259, Val loss 7.339
# Ep 1 (Step 002330): Train loss 7.296, Val loss 7.332
# Ep 1 (Step 002335): Train loss 7.247, Val loss 7.326
# Ep 1 (Step 002340): Train loss 7.238, Val loss 7.319
# Ep 1 (Step 002345): Train loss 7.263, Val loss 7.312
# Ep 1 (Step 002350): Train loss 7.266, Val loss 7.305
# Ep 1 (Step 002355): Train loss 7.305, Val loss 7.299
# Ep 1 (Step 002360): Train loss 7.254, Val loss 7.292
# Ep 1 (Step 002365): Train loss 7.205, Val loss 7.285
# Ep 1 (Step 002370): Train loss 7.238, Val loss 7.278
# Ep 1 (Step 002375): Train loss 7.211, Val loss 7.272
# Ep 1 (Step 002380): Train loss 7.225, Val loss 7.265
# Ep 1 (Step 002385): Train loss 7.217, Val loss 7.258
# Ep 1 (Step 002390): Train loss 7.170, Val loss 7.252
# Ep 1 (Step 002395): Train loss 7.173, Val loss 7.245
# Ep 1 (Step 002400): Train loss 7.229, Val loss 7.239
# Ep 1 (Step 002405): Train loss 7.177, Val loss 7.232
# Ep 1 (Step 002410): Train loss 7.174, Val loss 7.225
# Ep 1 (Step 002415): Train loss 7.232, Val loss 7.219
# Ep 1 (Step 002420): Train loss 7.187, Val loss 7.212
# Ep 1 (Step 002425): Train loss 7.156, Val loss 7.205
# Ep 1 (Step 002430): Train loss 7.183, Val loss 7.199
# Ep 1 (Step 002435): Train loss 7.071, Val loss 7.192
# Ep 1 (Step 002440): Train loss 7.105, Val loss 7.185
# Ep 1 (Step 002445): Train loss 7.150, Val loss 7.179
# Ep 1 (Step 002450): Train loss 7.089, Val loss 7.172
# Ep 1 (Step 002455): Train loss 7.142, Val loss 7.165
# Ep 1 (Step 002460): Train loss 7.134, Val loss 7.159
# Ep 1 (Step 002465): Train loss 7.107, Val loss 7.152
# Ep 1 (Step 002470): Train loss 7.155, Val loss 7.145
# Ep 1 (Step 002475): Train loss 7.090, Val loss 7.139
# Ep 1 (Step 002480): Train loss 7.075, Val loss 7.132
# Ep 1 (Step 002485): Train loss 7.083, Val loss 7.125
# Ep 1 (Step 002490): Train loss 7.060, Val loss 7.119
# Ep 1 (Step 002495): Train loss 7.074, Val loss 7.112
# Ep 1 (Step 002500): Train loss 7.019, Val loss 7.106
# Ep 1 (Step 002505): Train loss 7.053, Val loss 7.099
# Ep 1 (Step 002510): Train loss 7.020, Val loss 7.092
# Ep 1 (Step 002515): Train loss 7.019, Val loss 7.086
# Ep 1 (Step 002520): Train loss 7.032, Val loss 7.079
# Ep 1 (Step 002525): Train loss 6.992, Val loss 7.073
# Ep 1 (Step 002530): Train loss 6.950, Val loss 7.066
# Ep 1 (Step 002535): Train loss 7.044, Val loss 7.060
# Ep 1 (Step 002540): Train loss 7.052, Val loss 7.053
# Ep 1 (Step 002545): Train loss 6.957, Val loss 7.047
# Ep 1 (Step 002550): Train loss 6.953, Val loss 7.040
# Ep 1 (Step 002555): Train loss 6.964, Val loss 7.034
# Ep 1 (Step 002560): Train loss 6.977, Val loss 7.027
# Ep 1 (Step 002565): Train loss 6.976, Val loss 7.021
# Ep 1 (Step 002570): Train loss 6.947, Val loss 7.014
# Ep 1 (Step 002575): Train loss 6.967, Val loss 7.008
# Ep 1 (Step 002580): Train loss 6.932, Val loss 7.001
# Ep 1 (Step 002585): Train loss 6.953, Val loss 6.994
# Ep 1 (Step 002590): Train loss 6.933, Val loss 6.988
# Ep 1 (Step 002595): Train loss 6.953, Val loss 6.981
# Ep 1 (Step 002600): Train loss 6.970, Val loss 6.975
# Ep 1 (Step 002605): Train loss 6.938, Val loss 6.968
# Ep 1 (Step 002610): Train loss 6.934, Val loss 6.962
# Ep 1 (Step 002615): Train loss 6.908, Val loss 6.955
# Ep 1 (Step 002620): Train loss 6.854, Val loss 6.949
# Ep 1 (Step 002625): Train loss 6.929, Val loss 6.942
# Ep 1 (Step 002630): Train loss 6.870, Val loss 6.936
# Ep 1 (Step 002635): Train loss 6.833, Val loss 6.929
# Ep 1 (Step 002640): Train loss 6.909, Val loss 6.923
# Ep 1 (Step 002645): Train loss 6.837, Val loss 6.916
# Ep 1 (Step 002650): Train loss 6.840, Val loss 6.910
# Ep 1 (Step 002655): Train loss 6.842, Val loss 6.903
# Ep 1 (Step 002660): Train loss 6.837, Val loss 6.897
# Ep 1 (Step 002665): Train loss 6.844, Val loss 6.890
# Ep 1 (Step 002670): Train loss 6.749, Val loss 6.884
# Ep 1 (Step 002675): Train loss 6.812, Val loss 6.877
# Ep 1 (Step 002680): Train loss 6.773, Val loss 6.871
# Ep 1 (Step 002685): Train loss 6.832, Val loss 6.864
# Ep 1 (Step 002690): Train loss 6.777, Val loss 6.858
# Ep 1 (Step 002695): Train loss 6.788, Val loss 6.851
# Ep 1 (Step 002700): Train loss 6.731, Val loss 6.845
# Ep 1 (Step 002705): Train loss 6.760, Val loss 6.838
# Ep 1 (Step 002710): Train loss 6.799, Val loss 6.832
# Ep 1 (Step 002715): Train loss 6.753, Val loss 6.826
# Ep 1 (Step 002720): Train loss 6.830, Val loss 6.819
# Ep 1 (Step 002725): Train loss 6.750, Val loss 6.813
# Ep 1 (Step 002730): Train loss 6.769, Val loss 6.806
# Ep 1 (Step 002735): Train loss 6.757, Val loss 6.800
# Ep 1 (Step 002740): Train loss 6.774, Val loss 6.794
# Ep 1 (Step 002745): Train loss 6.724, Val loss 6.787
# Ep 1 (Step 002750): Train loss 6.795, Val loss 6.781
# Ep 1 (Step 002755): Train loss 6.687, Val loss 6.774
# Ep 1 (Step 002760): Train loss 6.651, Val loss 6.768
# Ep 1 (Step 002765): Train loss 6.722, Val loss 6.762
# Ep 1 (Step 002770): Train loss 6.734, Val loss 6.755
# Ep 1 (Step 002775): Train loss 6.763, Val loss 6.749
# Ep 1 (Step 002780): Train loss 6.722, Val loss 6.743
# Ep 1 (Step 002785): Train loss 6.614, Val loss 6.736
# Ep 1 (Step 002790): Train loss 6.599, Val loss 6.730
# Ep 1 (Step 002795): Train loss 6.657, Val loss 6.724
# Ep 1 (Step 002800): Train loss 6.692, Val loss 6.717
# Ep 1 (Step 002805): Train loss 6.623, Val loss 6.711
# Ep 1 (Step 002810): Train loss 6.629, Val loss 6.705
# Ep 1 (Step 002815): Train loss 6.694, Val loss 6.698
# Ep 1 (Step 002820): Train loss 6.662, Val loss 6.692
# Ep 1 (Step 002825): Train loss 6.654, Val loss 6.685
# Ep 1 (Step 002830): Train loss 6.657, Val loss 6.679
# Ep 1 (Step 002835): Train loss 6.625, Val loss 6.673
# Ep 1 (Step 002840): Train loss 6.569, Val loss 6.667
# Ep 1 (Step 002845): Train loss 6.562, Val loss 6.660
# Ep 1 (Step 002850): Train loss 6.588, Val loss 6.654
# Ep 1 (Step 002855): Train loss 6.569, Val loss 6.648
# Ep 1 (Step 002860): Train loss 6.576, Val loss 6.641
# Ep 1 (Step 002865): Train loss 6.556, Val loss 6.635
# Ep 1 (Step 002870): Train loss 6.553, Val loss 6.629
# Ep 1 (Step 002875): Train loss 6.577, Val loss 6.623
# Ep 1 (Step 002880): Train loss 6.542, Val loss 6.616
# Ep 1 (Step 002885): Train loss 6.553, Val loss 6.610
# Ep 1 (Step 002890): Train loss 6.676, Val loss 6.604
# Ep 1 (Step 002895): Train loss 6.527, Val loss 6.598
# Ep 1 (Step 002900): Train loss 6.503, Val loss 6.591
# Ep 1 (Step 002905): Train loss 6.553, Val loss 6.585
# Ep 1 (Step 002910): Train loss 6.565, Val loss 6.579
# Ep 1 (Step 002915): Train loss 6.491, Val loss 6.572
# Ep 1 (Step 002920): Train loss 6.466, Val loss 6.566
# Ep 1 (Step 002925): Train loss 6.511, Val loss 6.560
# Ep 1 (Step 002930): Train loss 6.492, Val loss 6.554
# Ep 1 (Step 002935): Train loss 6.534, Val loss 6.548
# Ep 1 (Step 002940): Train loss 6.535, Val loss 6.541
# Ep 1 (Step 002945): Train loss 6.485, Val loss 6.535
# Ep 1 (Step 002950): Train loss 6.451, Val loss 6.529
# Ep 1 (Step 002955): Train loss 6.450, Val loss 6.523
# Ep 1 (Step 002960): Train loss 6.419, Val loss 6.517
# Ep 1 (Step 002965): Train loss 6.498, Val loss 6.511
# Ep 1 (Step 002970): Train loss 6.445, Val loss 6.505
# Ep 1 (Step 002975): Train loss 6.459, Val loss 6.498
# Ep 1 (Step 002980): Train loss 6.449, Val loss 6.492
# Ep 1 (Step 002985): Train loss 6.370, Val loss 6.486
# Ep 1 (Step 002990): Train loss 6.471, Val loss 6.480
# Ep 1 (Step 002995): Train loss 6.401, Val loss 6.474
# Ep 1 (Step 003000): Train loss 6.419, Val loss 6.467
# Ep 1 (Step 003005): Train loss 6.427, Val loss 6.461
# Ep 1 (Step 003010): Train loss 6.394, Val loss 6.455
# Ep 1 (Step 003015): Train loss 6.414, Val loss 6.449
# Ep 1 (Step 003020): Train loss 6.360, Val loss 6.443
# Ep 1 (Step 003025): Train loss 6.352, Val loss 6.437
# Ep 1 (Step 003030): Train loss 6.350, Val loss 6.430
# Ep 1 (Step 003035): Train loss 6.370, Val loss 6.424
# Ep 1 (Step 003040): Train loss 6.399, Val loss 6.418
# Ep 1 (Step 003045): Train loss 6.479, Val loss 6.412
# Ep 1 (Step 003050): Train loss 6.386, Val loss 6.406
# Ep 1 (Step 003055): Train loss 6.357, Val loss 6.400
# Ep 1 (Step 003060): Train loss 6.297, Val loss 6.394
# Ep 1 (Step 003065): Train loss 6.315, Val loss 6.388
# Ep 1 (Step 003070): Train loss 6.372, Val loss 6.382
# Ep 1 (Step 003075): Train loss 6.267, Val loss 6.376
# Ep 1 (Step 003080): Train loss 6.328, Val loss 6.369
# Ep 1 (Step 003085): Train loss 6.304, Val loss 6.363
# Ep 1 (Step 003090): Train loss 6.290, Val loss 6.357
# Ep 1 (Step 003095): Train loss 6.326, Val loss 6.351
# Ep 1 (Step 003100): Train loss 6.348, Val loss 6.345
# Ep 1 (Step 003105): Train loss 6.252, Val loss 6.339
# Ep 1 (Step 003110): Train loss 6.294, Val loss 6.333
# Ep 1 (Step 003115): Train loss 6.242, Val loss 6.327
# Ep 1 (Step 003120): Train loss 6.290, Val loss 6.321
# Ep 1 (Step 003125): Train loss 6.244, Val loss 6.314
# Ep 1 (Step 003130): Train loss 6.184, Val loss 6.308
# Ep 1 (Step 003135): Train loss 6.194, Val loss 6.302
# Ep 1 (Step 003140): Train loss 6.222, Val loss 6.296
# Ep 1 (Step 003145): Train loss 6.233, Val loss 6.290
# Ep 1 (Step 003150): Train loss 6.248, Val loss 6.284
# Ep 1 (Step 003155): Train loss 6.210, Val loss 6.278
# Ep 1 (Step 003160): Train loss 6.265, Val loss 6.272
# Ep 1 (Step 003165): Train loss 6.253, Val loss 6.266
# Ep 1 (Step 003170): Train loss 6.250, Val loss 6.260
# Ep 1 (Step 003175): Train loss 6.158, Val loss 6.254
# Ep 1 (Step 003180): Train loss 6.264, Val loss 6.248
# Ep 1 (Step 003185): Train loss 6.160, Val loss 6.242
# Ep 1 (Step 003190): Train loss 6.182, Val loss 6.236
# Ep 1 (Step 003195): Train loss 6.160, Val loss 6.230
# Ep 1 (Step 003200): Train loss 6.094, Val loss 6.224
# Ep 1 (Step 003205): Train loss 6.228, Val loss 6.218
# Ep 1 (Step 003210): Train loss 6.060, Val loss 6.212
# Ep 1 (Step 003215): Train loss 6.136, Val loss 6.206
# Ep 1 (Step 003220): Train loss 6.149, Val loss 6.200
# Ep 1 (Step 003225): Train loss 6.246, Val loss 6.194
# Ep 1 (Step 003230): Train loss 6.166, Val loss 6.188
# Ep 1 (Step 003235): Train loss 6.110, Val loss 6.182
# Ep 1 (Step 003240): Train loss 6.097, Val loss 6.176
# Ep 1 (Step 003245): Train loss 6.071, Val loss 6.170
# Ep 1 (Step 003250): Train loss 6.140, Val loss 6.164
# Ep 1 (Step 003255): Train loss 6.124, Val loss 6.158
# Ep 1 (Step 003260): Train loss 6.089, Val loss 6.152
# Ep 1 (Step 003265): Train loss 6.124, Val loss 6.146
# Ep 1 (Step 003270): Train loss 6.105, Val loss 6.140
# Ep 1 (Step 003275): Train loss 6.036, Val loss 6.134
# Ep 1 (Step 003280): Train loss 6.056, Val loss 6.128
# Ep 1 (Step 003285): Train loss 6.080, Val loss 6.122
# Ep 1 (Step 003290): Train loss 6.004, Val loss 6.116
# Ep 1 (Step 003295): Train loss 6.032, Val loss 6.111
# Ep 1 (Step 003300): Train loss 5.991, Val loss 6.105
# Ep 1 (Step 003305): Train loss 5.995, Val loss 6.099
# Ep 1 (Step 003310): Train loss 5.918, Val loss 6.093
# Ep 1 (Step 003315): Train loss 6.016, Val loss 6.087
# Ep 1 (Step 003320): Train loss 6.025, Val loss 6.081
# Ep 1 (Step 003325): Train loss 5.983, Val loss 6.075
# Ep 1 (Step 003330): Train loss 6.066, Val loss 6.069
# Ep 1 (Step 003335): Train loss 5.985, Val loss 6.063
# Ep 1 (Step 003340): Train loss 5.923, Val loss 6.057
# Ep 1 (Step 003345): Train loss 5.931, Val loss 6.051
# Ep 1 (Step 003350): Train loss 6.084, Val loss 6.045
# Ep 1 (Step 003355): Train loss 5.929, Val loss 6.039
# Ep 1 (Step 003360): Train loss 5.948, Val loss 6.033
# Ep 1 (Step 003365): Train loss 5.978, Val loss 6.028
# Ep 1 (Step 003370): Train loss 5.963, Val loss 6.022
# Ep 1 (Step 003375): Train loss 5.873, Val loss 6.016
# Ep 1 (Step 003380): Train loss 5.944, Val loss 6.010
# Ep 1 (Step 003385): Train loss 5.873, Val loss 6.004
# Ep 1 (Step 003390): Train loss 5.951, Val loss 5.998
# Ep 1 (Step 003395): Train loss 5.915, Val loss 5.992
# Ep 1 (Step 003400): Train loss 5.886, Val loss 5.987
# Ep 1 (Step 003405): Train loss 5.902, Val loss 5.981
# Ep 1 (Step 003410): Train loss 5.969, Val loss 5.975
# Ep 1 (Step 003415): Train loss 5.892, Val loss 5.969
# Ep 1 (Step 003420): Train loss 5.904, Val loss 5.963
# Ep 1 (Step 003425): Train loss 5.919, Val loss 5.957
# Ep 1 (Step 003430): Train loss 5.874, Val loss 5.952
# Ep 1 (Step 003435): Train loss 5.858, Val loss 5.946
# Ep 1 (Step 003440): Train loss 5.920, Val loss 5.940
# Ep 1 (Step 003445): Train loss 5.803, Val loss 5.934
# Ep 1 (Step 003450): Train loss 5.887, Val loss 5.928
# Ep 1 (Step 003455): Train loss 5.815, Val loss 5.923
# Ep 1 (Step 003460): Train loss 5.815, Val loss 5.917
# Ep 1 (Step 003465): Train loss 5.883, Val loss 5.911
# Ep 1 (Step 003470): Train loss 5.779, Val loss 5.906
# Ep 1 (Step 003475): Train loss 5.880, Val loss 5.900
# Ep 1 (Step 003480): Train loss 5.837, Val loss 5.894
# Ep 1 (Step 003485): Train loss 5.847, Val loss 5.888
# Ep 1 (Step 003490): Train loss 5.812, Val loss 5.882
# Ep 1 (Step 003495): Train loss 5.761, Val loss 5.877
# Ep 1 (Step 003500): Train loss 5.773, Val loss 5.871
# Ep 1 (Step 003505): Train loss 5.818, Val loss 5.865
# Ep 1 (Step 003510): Train loss 5.772, Val loss 5.859
# Ep 1 (Step 003515): Train loss 5.760, Val loss 5.854
# Ep 1 (Step 003520): Train loss 5.795, Val loss 5.848
# Ep 1 (Step 003525): Train loss 5.775, Val loss 5.842
# Ep 1 (Step 003530): Train loss 5.715, Val loss 5.837
# Ep 1 (Step 003535): Train loss 5.785, Val loss 5.831
# Ep 1 (Step 003540): Train loss 5.797, Val loss 5.825
# Ep 1 (Step 003545): Train loss 5.728, Val loss 5.819
# Ep 1 (Step 003550): Train loss 5.755, Val loss 5.814
# Ep 1 (Step 003555): Train loss 5.739, Val loss 5.808
# Ep 1 (Step 003560): Train loss 5.754, Val loss 5.802
# Ep 1 (Step 003565): Train loss 5.782, Val loss 5.797
# Ep 1 (Step 003570): Train loss 5.763, Val loss 5.791
# Ep 1 (Step 003575): Train loss 5.873, Val loss 5.785
# Ep 1 (Step 003580): Train loss 5.682, Val loss 5.780
# Ep 1 (Step 003585): Train loss 5.731, Val loss 5.774
# Ep 1 (Step 003590): Train loss 5.720, Val loss 5.768
# Ep 1 (Step 003595): Train loss 5.671, Val loss 5.763
# Ep 1 (Step 003600): Train loss 5.655, Val loss 5.757
# Ep 1 (Step 003605): Train loss 5.709, Val loss 5.752
# Ep 1 (Step 003610): Train loss 5.679, Val loss 5.746
# Ep 1 (Step 003615): Train loss 5.694, Val loss 5.740
# Ep 1 (Step 003620): Train loss 5.706, Val loss 5.735
# Ep 1 (Step 003625): Train loss 5.659, Val loss 5.729
# Ep 1 (Step 003630): Train loss 5.652, Val loss 5.723
# Ep 1 (Step 003635): Train loss 5.661, Val loss 5.718
# Ep 1 (Step 003640): Train loss 5.627, Val loss 5.712
# Ep 1 (Step 003645): Train loss 5.627, Val loss 5.706
# Ep 1 (Step 003650): Train loss 5.664, Val loss 5.701
# Ep 1 (Step 003655): Train loss 5.613, Val loss 5.695
# Ep 1 (Step 003660): Train loss 5.652, Val loss 5.690
# Ep 1 (Step 003665): Train loss 5.688, Val loss 5.684
# Ep 1 (Step 003670): Train loss 5.585, Val loss 5.678
# Ep 1 (Step 003675): Train loss 5.547, Val loss 5.673
# Ep 1 (Step 003680): Train loss 5.570, Val loss 5.667
# Ep 1 (Step 003685): Train loss 5.676, Val loss 5.662
# Ep 1 (Step 003690): Train loss 5.625, Val loss 5.656
# Ep 1 (Step 003695): Train loss 5.591, Val loss 5.651
# Ep 1 (Step 003700): Train loss 5.538, Val loss 5.645
# Ep 1 (Step 003705): Train loss 5.666, Val loss 5.640
# Ep 1 (Step 003710): Train loss 5.603, Val loss 5.634
# Ep 1 (Step 003715): Train loss 5.531, Val loss 5.628
# Ep 1 (Step 003720): Train loss 5.551, Val loss 5.623
# Ep 1 (Step 003725): Train loss 5.522, Val loss 5.617
# Ep 1 (Step 003730): Train loss 5.604, Val loss 5.612
# Ep 1 (Step 003735): Train loss 5.523, Val loss 5.606
# Ep 1 (Step 003740): Train loss 5.503, Val loss 5.601
# Ep 1 (Step 003745): Train loss 5.600, Val loss 5.595
# Ep 1 (Step 003750): Train loss 5.474, Val loss 5.589
# Ep 1 (Step 003755): Train loss 5.516, Val loss 5.584
# Ep 1 (Step 003760): Train loss 5.497, Val loss 5.578
# Ep 1 (Step 003765): Train loss 5.518, Val loss 5.573
# Ep 1 (Step 003770): Train loss 5.470, Val loss 5.567
# Ep 1 (Step 003775): Train loss 5.615, Val loss 5.561
# Ep 1 (Step 003780): Train loss 5.450, Val loss 5.556
# Ep 1 (Step 003785): Train loss 5.522, Val loss 5.550
# Ep 1 (Step 003790): Train loss 5.412, Val loss 5.545
# Ep 1 (Step 003795): Train loss 5.498, Val loss 5.539
# Ep 1 (Step 003800): Train loss 5.459, Val loss 5.534
# Ep 1 (Step 003805): Train loss 5.438, Val loss 5.528
# Ep 1 (Step 003810): Train loss 5.463, Val loss 5.523
# Ep 1 (Step 003815): Train loss 5.402, Val loss 5.517
# Ep 1 (Step 003820): Train loss 5.361, Val loss 5.512
# Ep 1 (Step 003825): Train loss 5.473, Val loss 5.507
# Ep 1 (Step 003830): Train loss 5.440, Val loss 5.501
# Ep 1 (Step 003835): Train loss 5.443, Val loss 5.496
# Ep 1 (Step 003840): Train loss 5.280, Val loss 5.490
# Ep 1 (Step 003845): Train loss 5.460, Val loss 5.485
# Ep 1 (Step 003850): Train loss 5.454, Val loss 5.479
# Ep 1 (Step 003855): Train loss 5.415, Val loss 5.474
# Ep 1 (Step 003860): Train loss 5.413, Val loss 5.469
# Ep 1 (Step 003865): Train loss 5.360, Val loss 5.463
# Ep 1 (Step 003870): Train loss 5.394, Val loss 5.458
# Ep 1 (Step 003875): Train loss 5.398, Val loss 5.452
# Ep 1 (Step 003880): Train loss 5.404, Val loss 5.447
# Ep 1 (Step 003885): Train loss 5.392, Val loss 5.441
# Ep 1 (Step 003890): Train loss 5.336, Val loss 5.436
# Ep 1 (Step 003895): Train loss 5.408, Val loss 5.430
# Ep 1 (Step 003900): Train loss 5.329, Val loss 5.425
# Ep 1 (Step 003905): Train loss 5.399, Val loss 5.419
# Ep 1 (Step 003910): Train loss 5.391, Val loss 5.414
# Ep 1 (Step 003915): Train loss 5.248, Val loss 5.409
# Ep 1 (Step 003920): Train loss 5.282, Val loss 5.403
# Ep 1 (Step 003925): Train loss 5.321, Val loss 5.398
# Ep 1 (Step 003930): Train loss 5.252, Val loss 5.392
# Ep 1 (Step 003935): Train loss 5.327, Val loss 5.387
# Ep 1 (Step 003940): Train loss 5.257, Val loss 5.382
# Ep 1 (Step 003945): Train loss 5.425, Val loss 5.377
# Ep 1 (Step 003950): Train loss 5.198, Val loss 5.371
# Ep 1 (Step 003955): Train loss 5.371, Val loss 5.366
# Ep 1 (Step 003960): Train loss 5.202, Val loss 5.361
# Ep 1 (Step 003965): Train loss 5.269, Val loss 5.355
# Ep 1 (Step 003970): Train loss 5.316, Val loss 5.350
# Ep 1 (Step 003975): Train loss 5.378, Val loss 5.345
# Ep 1 (Step 003980): Train loss 5.302, Val loss 5.339
# Ep 1 (Step 003985): Train loss 5.318, Val loss 5.334
# Ep 1 (Step 003990): Train loss 5.153, Val loss 5.329
# Ep 1 (Step 003995): Train loss 5.160, Val loss 5.323
# Ep 1 (Step 004000): Train loss 5.202, Val loss 5.318
# Ep 1 (Step 004005): Train loss 5.201, Val loss 5.313
# Ep 1 (Step 004010): Train loss 5.252, Val loss 5.307
# Ep 1 (Step 004015): Train loss 5.263, Val loss 5.302
# Ep 1 (Step 004020): Train loss 5.147, Val loss 5.297
# Ep 1 (Step 004025): Train loss 5.177, Val loss 5.291
# Ep 1 (Step 004030): Train loss 5.230, Val loss 5.286
# Ep 1 (Step 004035): Train loss 5.148, Val loss 5.281
# Ep 1 (Step 004040): Train loss 5.207, Val loss 5.275
# Ep 1 (Step 004045): Train loss 5.225, Val loss 5.270
# Ep 1 (Step 004050): Train loss 5.205, Val loss 5.265
# Ep 1 (Step 004055): Train loss 5.112, Val loss 5.260
# Ep 1 (Step 004060): Train loss 5.269, Val loss 5.254
# Ep 1 (Step 004065): Train loss 5.116, Val loss 5.249
# Ep 1 (Step 004070): Train loss 5.152, Val loss 5.244
# Ep 1 (Step 004075): Train loss 5.096, Val loss 5.239
# Ep 1 (Step 004080): Train loss 5.076, Val loss 5.234
# Ep 1 (Step 004085): Train loss 5.076, Val loss 5.228
# Ep 1 (Step 004090): Train loss 5.149, Val loss 5.223
# Ep 1 (Step 004095): Train loss 5.101, Val loss 5.218
# Ep 1 (Step 004100): Train loss 5.182, Val loss 5.212
# Ep 1 (Step 004105): Train loss 5.193, Val loss 5.207
# Ep 1 (Step 004110): Train loss 5.239, Val loss 5.202
# Ep 1 (Step 004115): Train loss 5.041, Val loss 5.197
# Ep 1 (Step 004120): Train loss 5.099, Val loss 5.191
# Ep 1 (Step 004125): Train loss 5.133, Val loss 5.186
# Ep 1 (Step 004130): Train loss 5.157, Val loss 5.181
# Ep 1 (Step 004135): Train loss 5.022, Val loss 5.176
# Ep 1 (Step 004140): Train loss 5.180, Val loss 5.170
# Ep 1 (Step 004145): Train loss 5.092, Val loss 5.165
# Ep 1 (Step 004150): Train loss 5.034, Val loss 5.160
# Ep 1 (Step 004155): Train loss 5.050, Val loss 5.155
# Ep 1 (Step 004160): Train loss 5.102, Val loss 5.150
# Ep 1 (Step 004165): Train loss 5.004, Val loss 5.144
# Ep 1 (Step 004170): Train loss 5.084, Val loss 5.139
# Ep 1 (Step 004175): Train loss 5.028, Val loss 5.134
# Ep 1 (Step 004180): Train loss 5.001, Val loss 5.129
# Ep 1 (Step 004185): Train loss 5.027, Val loss 5.124
# Ep 1 (Step 004190): Train loss 5.062, Val loss 5.119
# Ep 1 (Step 004195): Train loss 5.071, Val loss 5.113
# Ep 1 (Step 004200): Train loss 5.050, Val loss 5.108
# Ep 1 (Step 004205): Train loss 5.101, Val loss 5.103
# Ep 1 (Step 004210): Train loss 4.985, Val loss 5.098
# Ep 1 (Step 004215): Train loss 5.121, Val loss 5.093
# Ep 1 (Step 004220): Train loss 4.965, Val loss 5.088
# Ep 1 (Step 004225): Train loss 4.898, Val loss 5.083
# Ep 1 (Step 004230): Train loss 5.050, Val loss 5.077
# Ep 1 (Step 004235): Train loss 5.021, Val loss 5.072
# Ep 1 (Step 004240): Train loss 5.094, Val loss 5.067
# Ep 1 (Step 004245): Train loss 4.979, Val loss 5.062
# Ep 1 (Step 004250): Train loss 5.010, Val loss 5.057
# Ep 1 (Step 004255): Train loss 4.948, Val loss 5.052
# Ep 1 (Step 004260): Train loss 5.065, Val loss 5.047
# Ep 1 (Step 004265): Train loss 5.003, Val loss 5.042
# Ep 1 (Step 004270): Train loss 4.981, Val loss 5.037
# Ep 1 (Step 004275): Train loss 5.008, Val loss 5.032
# Ep 1 (Step 004280): Train loss 4.940, Val loss 5.027
# Ep 1 (Step 004285): Train loss 4.900, Val loss 5.021
# Ep 1 (Step 004290): Train loss 4.981, Val loss 5.016
# Ep 1 (Step 004295): Train loss 4.940, Val loss 5.011
# Ep 1 (Step 004300): Train loss 4.938, Val loss 5.006
# Ep 1 (Step 004305): Train loss 5.005, Val loss 5.001
# Ep 1 (Step 004310): Train loss 4.898, Val loss 4.996
# Ep 1 (Step 004315): Train loss 4.873, Val loss 4.991
# Ep 1 (Step 004320): Train loss 4.802, Val loss 4.986
# Ep 1 (Step 004325): Train loss 4.971, Val loss 4.981
# Ep 1 (Step 004330): Train loss 4.948, Val loss 4.976
# Ep 1 (Step 004335): Train loss 4.821, Val loss 4.972
# Ep 1 (Step 004340): Train loss 4.936, Val loss 4.967
# Ep 1 (Step 004345): Train loss 4.965, Val loss 4.962
# Ep 1 (Step 004350): Train loss 4.963, Val loss 4.957
# Ep 1 (Step 004355): Train loss 5.018, Val loss 4.952
# Ep 1 (Step 004360): Train loss 4.807, Val loss 4.947
# Ep 1 (Step 004365): Train loss 4.762, Val loss 4.942
# Ep 1 (Step 004370): Train loss 4.864, Val loss 4.937
# Ep 1 (Step 004375): Train loss 4.962, Val loss 4.932
# Ep 1 (Step 004380): Train loss 4.943, Val loss 4.927
# Ep 1 (Step 004385): Train loss 4.803, Val loss 4.921
# Ep 1 (Step 004390): Train loss 4.873, Val loss 4.916
# Ep 1 (Step 004395): Train loss 4.889, Val loss 4.911
# Ep 1 (Step 004400): Train loss 4.885, Val loss 4.906
# Ep 1 (Step 004405): Train loss 4.930, Val loss 4.901
# Ep 1 (Step 004410): Train loss 4.876, Val loss 4.897
# Ep 1 (Step 004415): Train loss 4.788, Val loss 4.892
# Ep 1 (Step 004420): Train loss 4.983, Val loss 4.887
# Ep 1 (Step 004425): Train loss 4.799, Val loss 4.882
# Ep 1 (Step 004430): Train loss 4.876, Val loss 4.877
# Ep 1 (Step 004435): Train loss 4.857, Val loss 4.872
# Ep 1 (Step 004440): Train loss 4.785, Val loss 4.867
# Ep 1 (Step 004445): Train loss 4.672, Val loss 4.862
# Ep 1 (Step 004450): Train loss 4.809, Val loss 4.857
# Ep 1 (Step 004455): Train loss 4.711, Val loss 4.852
# Ep 1 (Step 004460): Train loss 4.799, Val loss 4.848
# Ep 1 (Step 004465): Train loss 4.806, Val loss 4.843
# Ep 1 (Step 004470): Train loss 4.793, Val loss 4.838
# Ep 1 (Step 004475): Train loss 4.788, Val loss 4.833
# Ep 1 (Step 004480): Train loss 4.632, Val loss 4.828
# Ep 1 (Step 004485): Train loss 4.670, Val loss 4.823
# Ep 1 (Step 004490): Train loss 4.716, Val loss 4.818
# Ep 1 (Step 004495): Train loss 4.776, Val loss 4.813
# Ep 1 (Step 004500): Train loss 4.749, Val loss 4.809
# Ep 1 (Step 004505): Train loss 4.707, Val loss 4.804
# Ep 1 (Step 004510): Train loss 4.786, Val loss 4.799
# Ep 1 (Step 004515): Train loss 4.688, Val loss 4.794
# Ep 1 (Step 004520): Train loss 4.791, Val loss 4.789
# Ep 1 (Step 004525): Train loss 4.676, Val loss 4.784
# Ep 1 (Step 004530): Train loss 4.644, Val loss 4.780
# Ep 1 (Step 004535): Train loss 4.672, Val loss 4.775
# Ep 1 (Step 004540): Train loss 4.741, Val loss 4.770
# Ep 1 (Step 004545): Train loss 4.697, Val loss 4.765
# Ep 1 (Step 004550): Train loss 4.718, Val loss 4.760
# Ep 1 (Step 004555): Train loss 4.651, Val loss 4.756
# Ep 1 (Step 004560): Train loss 4.636, Val loss 4.751
# Ep 1 (Step 004565): Train loss 4.771, Val loss 4.746
# Ep 1 (Step 004570): Train loss 4.802, Val loss 4.741
# Ep 1 (Step 004575): Train loss 4.560, Val loss 4.736
# Ep 1 (Step 004580): Train loss 4.683, Val loss 4.731
# Ep 1 (Step 004585): Train loss 4.717, Val loss 4.726
# Ep 1 (Step 004590): Train loss 4.658, Val loss 4.722
# Ep 1 (Step 004595): Train loss 4.643, Val loss 4.717
# Ep 1 (Step 004600): Train loss 4.705, Val loss 4.712
# Ep 1 (Step 004605): Train loss 4.703, Val loss 4.707
# Ep 1 (Step 004610): Train loss 4.644, Val loss 4.703
# Ep 1 (Step 004615): Train loss 4.558, Val loss 4.698
# Ep 1 (Step 004620): Train loss 4.738, Val loss 4.693
# Ep 1 (Step 004625): Train loss 4.592, Val loss 4.688
# Ep 1 (Step 004630): Train loss 4.622, Val loss 4.684
# Ep 1 (Step 004635): Train loss 4.558, Val loss 4.679
# Ep 1 (Step 004640): Train loss 4.640, Val loss 4.674
# Ep 1 (Step 004645): Train loss 4.558, Val loss 4.669
# Ep 1 (Step 004650): Train loss 4.499, Val loss 4.665
# Ep 1 (Step 004655): Train loss 4.591, Val loss 4.660
# Ep 1 (Step 004660): Train loss 4.633, Val loss 4.655
# Ep 1 (Step 004665): Train loss 4.500, Val loss 4.651
# Ep 1 (Step 004670): Train loss 4.666, Val loss 4.646
# Ep 1 (Step 004675): Train loss 4.531, Val loss 4.641
# Ep 1 (Step 004680): Train loss 4.474, Val loss 4.637
# Ep 1 (Step 004685): Train loss 4.559, Val loss 4.632
# Ep 1 (Step 004690): Train loss 4.629, Val loss 4.627
# Ep 1 (Step 004695): Train loss 4.499, Val loss 4.623
# Ep 1 (Step 004700): Train loss 4.601, Val loss 4.618
# Ep 1 (Step 004705): Train loss 4.350, Val loss 4.613
# Ep 1 (Step 004710): Train loss 4.682, Val loss 4.609
# Ep 1 (Step 004715): Train loss 4.476, Val loss 4.604
# Ep 1 (Step 004720): Train loss 4.562, Val loss 4.599
# Ep 1 (Step 004725): Train loss 4.446, Val loss 4.595
# Ep 1 (Step 004730): Train loss 4.612, Val loss 4.590
# Ep 1 (Step 004735): Train loss 4.583, Val loss 4.585
# Ep 1 (Step 004740): Train loss 4.492, Val loss 4.581
# Ep 1 (Step 004745): Train loss 4.530, Val loss 4.576
# Ep 1 (Step 004750): Train loss 4.555, Val loss 4.571
# Ep 1 (Step 004755): Train loss 4.409, Val loss 4.566
# Ep 1 (Step 004760): Train loss 4.546, Val loss 4.562
# Ep 1 (Step 004765): Train loss 4.525, Val loss 4.557
# Ep 1 (Step 004770): Train loss 4.426, Val loss 4.553
# Ep 1 (Step 004775): Train loss 4.512, Val loss 4.548
# Ep 1 (Step 004780): Train loss 4.551, Val loss 4.543
# Ep 1 (Step 004785): Train loss 4.319, Val loss 4.539
# Ep 1 (Step 004790): Train loss 4.499, Val loss 4.534
# Ep 1 (Step 004795): Train loss 4.351, Val loss 4.530
# Ep 1 (Step 004800): Train loss 4.569, Val loss 4.525
# Ep 1 (Step 004805): Train loss 4.478, Val loss 4.521
# Ep 1 (Step 004810): Train loss 4.479, Val loss 4.516
# Ep 1 (Step 004815): Train loss 4.360, Val loss 4.511
# Ep 1 (Step 004820): Train loss 4.417, Val loss 4.507
# Ep 1 (Step 004825): Train loss 4.411, Val loss 4.502
# Ep 1 (Step 004830): Train loss 4.427, Val loss 4.498
# Ep 1 (Step 004835): Train loss 4.356, Val loss 4.493
# Ep 1 (Step 004840): Train loss 4.492, Val loss 4.489
# Ep 1 (Step 004845): Train loss 4.373, Val loss 4.484
# Ep 1 (Step 004850): Train loss 4.356, Val loss 4.480
# Ep 1 (Step 004855): Train loss 4.574, Val loss 4.475
# Ep 1 (Step 004860): Train loss 4.344, Val loss 4.471
# Ep 1 (Step 004865): Train loss 4.506, Val loss 4.466
# Ep 1 (Step 004870): Train loss 4.565, Val loss 4.462
# Ep 1 (Step 004875): Train loss 4.307, Val loss 4.458
# Ep 1 (Step 004880): Train loss 4.348, Val loss 4.453
# Ep 1 (Step 004885): Train loss 4.371, Val loss 4.449
# Ep 1 (Step 004890): Train loss 4.234, Val loss 4.444
# Ep 1 (Step 004895): Train loss 4.404, Val loss 4.440
# Ep 1 (Step 004900): Train loss 4.259, Val loss 4.435
# Ep 1 (Step 004905): Train loss 4.465, Val loss 4.431
# Ep 1 (Step 004910): Train loss 4.329, Val loss 4.426
# Ep 1 (Step 004915): Train loss 4.309, Val loss 4.422
# Ep 1 (Step 004920): Train loss 4.245, Val loss 4.417
# Ep 1 (Step 004925): Train loss 4.248, Val loss 4.413
# Ep 1 (Step 004930): Train loss 4.384, Val loss 4.408
# Ep 1 (Step 004935): Train loss 4.432, Val loss 4.404
# Ep 1 (Step 004940): Train loss 4.321, Val loss 4.399
# Ep 1 (Step 004945): Train loss 4.521, Val loss 4.395
# Ep 1 (Step 004950): Train loss 4.467, Val loss 4.390
# Ep 1 (Step 004955): Train loss 4.253, Val loss 4.386
# Ep 1 (Step 004960): Train loss 4.475, Val loss 4.381
# Ep 1 (Step 004965): Train loss 4.186, Val loss 4.377
# Ep 1 (Step 004970): Train loss 4.128, Val loss 4.373
# Ep 1 (Step 004975): Train loss 4.216, Val loss 4.368
# Ep 1 (Step 004980): Train loss 4.309, Val loss 4.364
# Ep 1 (Step 004985): Train loss 4.392, Val loss 4.359
# Ep 1 (Step 004990): Train loss 4.191, Val loss 4.355
# Ep 1 (Step 004995): Train loss 4.247, Val loss 4.351
# Ep 1 (Step 005000): Train loss 4.263, Val loss 4.346
# Ep 1 (Step 005005): Train loss 4.330, Val loss 4.342
# Ep 1 (Step 005010): Train loss 4.302, Val loss 4.337
# Ep 1 (Step 005015): Train loss 4.209, Val loss 4.333
# Ep 1 (Step 005020): Train loss 4.245, Val loss 4.329
# Ep 1 (Step 005025): Train loss 4.105, Val loss 4.324
# Ep 1 (Step 005030): Train loss 4.183, Val loss 4.320
# Ep 1 (Step 005035): Train loss 4.324, Val loss 4.316
# Ep 1 (Step 005040): Train loss 4.243, Val loss 4.312
# Ep 1 (Step 005045): Train loss 4.229, Val loss 4.307
# Ep 1 (Step 005050): Train loss 4.273, Val loss 4.303
# Ep 1 (Step 005055): Train loss 4.133, Val loss 4.299
# Ep 1 (Step 005060): Train loss 4.106, Val loss 4.294
# Ep 1 (Step 005065): Train loss 4.152, Val loss 4.290
# Ep 1 (Step 005070): Train loss 4.040, Val loss 4.286
# Ep 1 (Step 005075): Train loss 4.346, Val loss 4.281
# Ep 1 (Step 005080): Train loss 4.133, Val loss 4.277
# Ep 1 (Step 005085): Train loss 4.241, Val loss 4.273
# Ep 1 (Step 005090): Train loss 4.163, Val loss 4.268
# Ep 1 (Step 005095): Train loss 4.131, Val loss 4.264
# Ep 1 (Step 005100): Train loss 4.135, Val loss 4.260
# Ep 1 (Step 005105): Train loss 4.177, Val loss 4.255
# Ep 1 (Step 005110): Train loss 4.184, Val loss 4.251
# Ep 1 (Step 005115): Train loss 4.171, Val loss 4.247
# Ep 1 (Step 005120): Train loss 4.046, Val loss 4.243
# Ep 1 (Step 005125): Train loss 4.318, Val loss 4.239
# Ep 1 (Step 005130): Train loss 4.130, Val loss 4.234
# Ep 1 (Step 005135): Train loss 4.139, Val loss 4.230
# Ep 1 (Step 005140): Train loss 4.215, Val loss 4.226
# Ep 1 (Step 005145): Train loss 3.995, Val loss 4.222
# Ep 1 (Step 005150): Train loss 4.188, Val loss 4.217
# Ep 1 (Step 005155): Train loss 4.252, Val loss 4.213
# Ep 1 (Step 005160): Train loss 3.999, Val loss 4.209
# Ep 1 (Step 005165): Train loss 4.138, Val loss 4.205
# Ep 1 (Step 005170): Train loss 4.105, Val loss 4.201
# Ep 1 (Step 005175): Train loss 4.139, Val loss 4.196
# Ep 1 (Step 005180): Train loss 4.225, Val loss 4.192
# Ep 1 (Step 005185): Train loss 4.097, Val loss 4.188
# Ep 1 (Step 005190): Train loss 4.056, Val loss 4.184
# Ep 1 (Step 005195): Train loss 4.033, Val loss 4.180
# Ep 1 (Step 005200): Train loss 4.209, Val loss 4.175
# Ep 1 (Step 005205): Train loss 4.120, Val loss 4.171
# Ep 1 (Step 005210): Train loss 4.121, Val loss 4.167
# Ep 1 (Step 005215): Train loss 3.982, Val loss 4.163
# Ep 1 (Step 005220): Train loss 4.059, Val loss 4.159
# Ep 1 (Step 005225): Train loss 4.012, Val loss 4.155
# Ep 1 (Step 005230): Train loss 4.012, Val loss 4.150
# Ep 1 (Step 005235): Train loss 4.037, Val loss 4.146
# Ep 1 (Step 005240): Train loss 4.005, Val loss 4.142
# Ep 1 (Step 005245): Train loss 4.048, Val loss 4.138
# Ep 1 (Step 005250): Train loss 3.983, Val loss 4.134
# Ep 1 (Step 005255): Train loss 4.004, Val loss 4.130
# Ep 1 (Step 005260): Train loss 3.951, Val loss 4.126
# Ep 1 (Step 005265): Train loss 4.033, Val loss 4.122
# Ep 1 (Step 005270): Train loss 4.066, Val loss 4.118
# Ep 1 (Step 005275): Train loss 4.056, Val loss 4.114
# Ep 1 (Step 005280): Train loss 3.996, Val loss 4.109
# Ep 1 (Step 005285): Train loss 4.036, Val loss 4.105
# Ep 1 (Step 005290): Train loss 3.952, Val loss 4.101
# Ep 1 (Step 005295): Train loss 3.933, Val loss 4.097
# Ep 1 (Step 005300): Train loss 4.079, Val loss 4.093
# Ep 1 (Step 005305): Train loss 3.990, Val loss 4.089
# Ep 1 (Step 005310): Train loss 4.075, Val loss 4.085
# Ep 1 (Step 005315): Train loss 3.935, Val loss 4.081
# Ep 1 (Step 005320): Train loss 3.962, Val loss 4.077
# Ep 1 (Step 005325): Train loss 3.938, Val loss 4.073
# Ep 1 (Step 005330): Train loss 3.958, Val loss 4.069
# Ep 1 (Step 005335): Train loss 3.923, Val loss 4.065
# Ep 1 (Step 005340): Train loss 4.146, Val loss 4.061
# Ep 1 (Step 005345): Train loss 3.942, Val loss 4.057
# Ep 1 (Step 005350): Train loss 3.921, Val loss 4.053
# Ep 1 (Step 005355): Train loss 4.040, Val loss 4.049
# Ep 1 (Step 005360): Train loss 3.884, Val loss 4.045
# Ep 1 (Step 005365): Train loss 4.118, Val loss 4.041
# Ep 1 (Step 005370): Train loss 3.992, Val loss 4.037
# Ep 1 (Step 005375): Train loss 3.834, Val loss 4.033
# Ep 1 (Step 005380): Train loss 4.036, Val loss 4.029
# Ep 1 (Step 005385): Train loss 3.857, Val loss 4.025
# Ep 1 (Step 005390): Train loss 3.940, Val loss 4.021
# Ep 1 (Step 005395): Train loss 3.908, Val loss 4.017
# Ep 1 (Step 005400): Train loss 3.805, Val loss 4.013
# Ep 1 (Step 005405): Train loss 4.012, Val loss 4.009
# Ep 1 (Step 005410): Train loss 3.963, Val loss 4.005
# Ep 1 (Step 005415): Train loss 3.811, Val loss 4.001
# Ep 1 (Step 005420): Train loss 3.919, Val loss 3.997
# Ep 1 (Step 005425): Train loss 3.733, Val loss 3.993
# Ep 1 (Step 005430): Train loss 3.888, Val loss 3.990
# Ep 1 (Step 005435): Train loss 3.843, Val loss 3.986
# Ep 1 (Step 005440): Train loss 3.729, Val loss 3.982
# Ep 1 (Step 005445): Train loss 4.035, Val loss 3.978
# Ep 1 (Step 005450): Train loss 3.779, Val loss 3.974
# Ep 1 (Step 005455): Train loss 3.909, Val loss 3.970
# Ep 1 (Step 005460): Train loss 3.824, Val loss 3.966
# Ep 1 (Step 005465): Train loss 3.784, Val loss 3.962
# Ep 1 (Step 005470): Train loss 3.817, Val loss 3.958
# Ep 1 (Step 005475): Train loss 3.840, Val loss 3.954
# Ep 1 (Step 005480): Train loss 3.782, Val loss 3.950
# Ep 1 (Step 005485): Train loss 3.914, Val loss 3.946
# Ep 1 (Step 005490): Train loss 3.868, Val loss 3.942
# Ep 1 (Step 005495): Train loss 3.700, Val loss 3.939
# Ep 1 (Step 005500): Train loss 3.739, Val loss 3.935
# Ep 1 (Step 005505): Train loss 3.785, Val loss 3.931
# Ep 1 (Step 005510): Train loss 3.909, Val loss 3.927
# Ep 1 (Step 005515): Train loss 3.847, Val loss 3.923
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 train_model_simple(
#       2     litmodel.model, litmodel.train_dataloader(), litmodel.val_dataloader(),
#       3     litmodel.configure_optimizers(), device, trainer_config["epochs"],
#       4     eval_freq=5, eval_iter=5, start_context="Once upon a time", tokenizer=tokenizer
#       5 )
#
# Cell In[10], line 11, in train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs, eval_freq, eval_iter, start_context, tokenizer)
#       9 for input_batch, target_batch in train_loader:
#      10     optimizer.zero_grad()
# ---> 11     loss = calc_loss_batch(
#      12         input_batch, target_batch, model, device
#      13     )
#      14     loss.backward()
#      15     optimizer.step()
#
# Cell In[9], line 5, in calc_loss_batch(input_batch, target_batch, model, device)
#       4 def calc_loss_batch(input_batch, target_batch, model, device):
# ----> 5     input_batch = input_batch.clone().detach().to(device)
#       8     logits = model(input_batch)
#       9     target_batch = target_batch.clone().detach().to(device)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(litmodel.train_losses, label="Training Loss", color="blue")
ax1.scatter(litmodel.val_steps, litmodel.val_losses, label="Validation Loss", color="red")
ax1.set_xlabel("Training Step")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper left")

ax2 = ax1.twinx()
ax2.plot(litmodel.learning_rates, label="Learning Rate", color="green")
ax2.set_ylabel("Learning Rate")
ax2.legend(loc="upper right")

plt.title("Training/Validation Loss and Learning Rate")
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(litmodel.train_accuracy, color="blue")
plt.scatter(litmodel.val_steps, litmodel.val_accuracy, color="red")
plt.xlabel("Training Step")
plt.ylabel("Accuracy")
plt.grid(True)
plt.ylim(0, 1)
plt.show()

# %%
from tokenizers import Tokenizer

# %%
tokenizer = Tokenizer.from_file("./TinyStories_tokenizer.json")

# %%
from tokenizers import decoders
tokenizer.decoder = decoders.WordPiece()

# %%
from components.generatetext import generate_text

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
litmodel.model.to(device)

# %%
# %%time
litmodel.eval()
starting_text = "Tom and Jane are friends. One day, Jane goes to Tom’s house. Tom has a big pot of soup. He wants to share it with Jane. “Jane, do you want some soup?” Tom asks. “Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is"
text = generate_text(litmodel.model, tokenizer, starting_text, 512, device, topk=3, temperature=1)
print("text: ", text)

# %%
# %%time
litmodel.eval()
starting_text = "Tom and Jane are friends. One day, Jane goes to Tom’s house. Tom has a big pot of soup. He wants to share it with Jane. “Jane, do you want some soup?” Tom asks. “Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is"
text = generate_text(litmodel.model, tokenizer, starting_text, 512, device, topk=3, temperature=1)
print("text: ", text)

# %%
# %%time
litmodel.eval()
starting_text = "Tom and Jane are friends. One day, Jane goes to Tom’s house. Tom has a big pot of soup. He wants to share it with Jane. “Jane, do you want some soup?” Tom asks. “Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is"
text = generate_text(litmodel.model, tokenizer, starting_text, 512, device, topk=3, temperature=1)
print("text: ", text)

# %%
# %%time
litmodel.eval()
starting_text = "Tom and Jane are friends. One day, Jane goes to Tom’s house. Tom has a big pot of soup. He wants to share it with Jane. “Jane, do you want some soup?” Tom asks. “Yes, please. It looks yummy,” Jane says. Tom pours some soup into two bowls. He gives one bowl to Jane. Jane takes a spoonful of soup, but then she makes a face. The soup is"
text = generate_text(litmodel.model, tokenizer, starting_text, 512, device, topk=3, temperature=1)
print("text: ", text)
